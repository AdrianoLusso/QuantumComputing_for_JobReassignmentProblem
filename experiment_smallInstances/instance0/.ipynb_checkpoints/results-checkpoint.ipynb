# %% [markdown]
# # Results for instance 0

# %% [markdown]
# This notebook shows the results over the previously experiments done

# %%
import json
import os
import matplotlib.pyplot as plt
from openqaoa.algorithms import QAOAResult
from openqaoa.qaoa_components import Hamiltonian,PauliOp
import numpy as np

# %% [markdown]
# ## Upload json files

# %%
results = []
file_names=['cpu_statevector','gpu_statevector']

for file_name in file_names:
    file_route = os.path.join('./',file_name+'.json')
    with open(file_route, "r") as file:
        result = json.load(file)
        #print(result)
        #result = QAOAResult.from_dict(result)
        results.append(result)

# %%
#results[0]

# %% [markdown]
# This is an important step. The data imported is in json format. For using the multiple analysis functions that OpenQAOA, we need to create the respective objects with the dict. For that we should:
#
# 1. Create the PauliOp objects for each cost hamiltonian
# 2. Once we have the PauliOp objects, we create each Hamiltonian object
# 3. Once we have the Hamiltonian object, we create the QAOAResult obejct

# %%
maxfevs=['100','250','500','750','1000']
for itr,result in enumerate(results):
    for maxfev in maxfevs:
        # get the QAOA result as dict
        result_dict = results[itr]['maxfev '+maxfev]['result']

        # get cost hamiltonian as dict
        hamiltonian_dict = result_dict['cost_hamiltonian']

        # for each pauliOp represented as dict, convert it to an object
        for itr2,pauliOp_dict in enumerate(hamiltonian_dict['terms']):
            qubit_indices = pauliOp_dict['qubit_indices']
            pauli_str = pauliOp_dict['pauli_str']

            hamiltonian_dict['terms'][itr2] = PauliOp(pauli_str,qubit_indices)

        # now that we have PauliOp objects, we can create the Hamiltonian object for the cost hamiltonian
        result_dict['cost_hamiltonian'] = Hamiltonian(hamiltonian_dict['terms'],hamiltonian_dict['coeffs'],hamiltonian_dict['constant']) 

        # now that we have the Hamiltonian object, we can create que QAOAResult object
        results[itr]['maxfev '+maxfev]['result'] = QAOAResult.from_dict(result_dict)

# %% [markdown]
# One that we have the QAOAResult object, we can make use of a useful function called  $\texttt{lowest\_cost\_bitstrings(n)}$ . This return the $n$ most approximates solutions found by the QAOA optimization. For each one, it show the respective bitstring, its energy(cost) and it occurance probability.
#
# Here, it is important to notice that, if the QAOA is not correctly configured, $\textbf{the most approximates solutions found will be bad solutions by nature}$. Remember that this function just analyze the solutions found by the QAOA optimization, not the whole search space. That means, if an optimal solution is not found by the QAOA optimization, this function will not show it.
#
# For this notebook, we will took the 10 most approximates solutions found.

# %%
lowest_cost_bitstrings = []
for itr,result in enumerate(results):
    lowest_cost_bitstrings.append([])
    for maxfev in maxfevs:
        #lowest_cost_bitstrings = result['maxfev '+maxfev]['result'].lowest_cost_bitstrings(10)
       # probabilities.append(
        #    lowest_cost_bitstrings
       # )
        lowest_cost_bitstrings[itr].append(result['maxfev '+maxfev]['result'].lowest_cost_bitstrings(10))

# %%
lowest_cost_bitstrings
# Out:
# [[{'solutions_bitstrings': ['000000000001000',
#     '000000001100000',
#     '000000100001000',
#     '000000001000000',
#     '000000000100001',
#     '000000001010000',
#     '000000000001100',
#     '000000001001000',
#     '000000000000001',
#     '000000010001000'],
#    'bitstrings_energies': [-3.9200000000000017,
#     -3.0600000000000023,
#     -2.969999999999999,
#     -2.950000000000003,
#     -2.9200000000000017,
#     -2.9000000000000057,
#     -2.8799999999999955,
#     -2.8700000000000045,
#     -2.8100000000000023,
#     -2.7900000000000063],
#    'probabilities': [0.3893,
#     0.012,
#     0.0119,
#     0.04,
#     0.0086,
#     0.0081,
#     0.0115,
#     0.0348,
#     0.0241,
#     0.0108]},
#   {'solutions_bitstrings': ['000000000001000',
#     '000000001100000',
#     '000000100001000',
#     '000000001000000',
#     '000000000100001',
#     '000000001010000',
#     '000000000001100',
#     '000000001001000',
#     '000000000000001',
#     '000000010001000'],
#    'bitstrings_energies': [-3.9200000000000017,
#     -3.0600000000000023,
#     -2.969999999999999,
#     -2.950000000000003,
#     -2.9200000000000017,
#     -2.9000000000000057,
#     -2.8799999999999955,
#     -2.8700000000000045,
#     -2.8100000000000023,
#     -2.7900000000000063],
#    'probabilities': [0.4007,
#     0.0132,
#     0.0093,
#     0.0477,
#     0.011,
#     0.0069,
#     0.0101,
#     0.0277,
#     0.0314,
#     0.0095]},
#   {'solutions_bitstrings': ['000000000001000',
#     '000000001100000',
#     '000000100001000',
#     '000000001000000',
#     '000000000100001',
#     '000000001010000',
#     '000000000001100',
#     '000000001001000',
#     '000000000000001',
#     '000000010001000'],
#    'bitstrings_energies': [-3.9200000000000017,
#     -3.0600000000000023,
#     -2.969999999999999,
#     -2.950000000000003,
#     -2.9200000000000017,
#     -2.9000000000000057,
#     -2.8799999999999955,
#     -2.8700000000000045,
#     -2.8100000000000023,
#     -2.7900000000000063],
#    'probabilities': [0.4572,
#     0.0104,
#     0.0092,
#     0.0613,
#     0.0073,
#     0.005,
#     0.009,
#     0.0241,
#     0.0409,
#     0.0075]},
#   {'solutions_bitstrings': ['000000000001000',
#     '000000001100000',
#     '000000100001000',
#     '000000001000000',
#     '000000000100001',
#     '000000001010000',
#     '000000000001100',
#     '000000001001000',
#     '000000000000001',
#     '000000010001000'],
#    'bitstrings_energies': [-3.9200000000000017,
#     -3.0600000000000023,
#     -2.969999999999999,
#     -2.950000000000003,
#     -2.9200000000000017,
#     -2.9000000000000057,
#     -2.8799999999999955,
#     -2.8700000000000045,
#     -2.8100000000000023,
#     -2.7900000000000063],
#    'probabilities': [0.4249,
#     0.0105,
#     0.0079,
#     0.0658,
#     0.009,
#     0.0054,
#     0.0063,
#     0.0237,
#     0.0437,
#     0.0059]},
#   {'solutions_bitstrings': ['000000000001000',
#     '000000001100000',
#     '000000100001000',
#     '000000001000000',
#     '000000000100001',
#     '000000001010000',
#     '000000000001100',
#     '000000001001000',
#     '000000000000001',
#     '000000010001000'],
#    'bitstrings_energies': [-3.9200000000000017,
#     -3.0600000000000023,
#     -2.969999999999999,
#     -2.950000000000003,
#     -2.9200000000000017,
#     -2.9000000000000057,
#     -2.8799999999999955,
#     -2.8700000000000045,
#     -2.8100000000000023,
#     -2.7900000000000063],
#    'probabilities': [0.4522,
#     0.0091,
#     0.0147,
#     0.0491,
#     0.0068,
#     0.0069,
#     0.0101,
#     0.0302,
#     0.0289,
#     0.0111]}],
#  [{'solutions_bitstrings': ['000000000001000',
#     '000000001100000',
#     '000000100001000',
#     '000000001000000',
#     '000000000100001',
#     '000000001010000',
#     '000000000001100',
#     '000000001001000',
#     '000000000000001',
#     '000000010001000'],
#    'bitstrings_energies': [-3.9200000000000017,
#     -3.0600000000000023,
#     -2.969999999999999,
#     -2.950000000000003,
#     -2.9200000000000017,
#     -2.9000000000000057,
#     -2.8799999999999955,
#     -2.8700000000000045,
#     -2.8100000000000023,
#     -2.7900000000000063],
#    'probabilities': [0.3895,
#     0.0119,
#     0.0122,
#     0.0349,
#     0.0098,
#     0.0072,
#     0.0093,
#     0.0305,
#     0.0248,
#     0.0106]},
#   {'solutions_bitstrings': ['000000000001000',
#     '000000001100000',
#     '000000100001000',
#     '000000001000000',
#     '000000000100001',
#     '000000001010000',
#     '000000000001100',
#     '000000001001000',
#     '000000000000001',
#     '000000010001000'],
#    'bitstrings_energies': [-3.9200000000000017,
#     -3.0600000000000023,
#     -2.969999999999999,
#     -2.950000000000003,
#     -2.9200000000000017,
#     -2.9000000000000057,
#     -2.8799999999999955,
#     -2.8700000000000045,
#     -2.8100000000000023,
#     -2.7900000000000063],
#    'probabilities': [0.4658,
#     0.0115,
#     0.0106,
#     0.0584,
#     0.0074,
#     0.0051,
#     0.0068,
#     0.0173,
#     0.0427,
#     0.0063]},
#   {'solutions_bitstrings': ['000000000001000',
#     '000000001100000',
#     '000000100001000',
#     '000000001000000',
#     '000000000100001',
#     '000000001010000',
#     '000000000001100',
#     '000000001001000',
#     '000000000000001',
#     '000000010001000'],
#    'bitstrings_energies': [-3.9200000000000017,
#     -3.0600000000000023,
#     -2.969999999999999,
#     -2.950000000000003,
#     -2.9200000000000017,
#     -2.9000000000000057,
#     -2.8799999999999955,
#     -2.8700000000000045,
#     -2.8100000000000023,
#     -2.7900000000000063],
#    'probabilities': [0.3973,
#     0.0154,
#     0.0115,
#     0.0445,
#     0.0081,
#     0.0057,
#     0.0103,
#     0.0292,
#     0.0271,
#     0.0106]},
#   {'solutions_bitstrings': ['000000000001000',
#     '000000001100000',
#     '000000100001000',
#     '000000001000000',
#     '000000000100001',
#     '000000001010000',
#     '000000000001100',
#     '000000001001000',
#     '000000000000001',
#     '000000010001000'],
#    'bitstrings_energies': [-3.9200000000000017,
#     -3.0600000000000023,
#     -2.969999999999999,
#     -2.950000000000003,
#     -2.9200000000000017,
#     -2.9000000000000057,
#     -2.8799999999999955,
#     -2.8700000000000045,
#     -2.8100000000000023,
#     -2.7900000000000063],
#    'probabilities': [0.4783,
#     0.0149,
#     0.0077,
#     0.0741,
#     0.0094,
#     0.0042,
#     0.0076,
#     0.0229,
#     0.0506,
#     0.0063]},
#   {'solutions_bitstrings': ['000000000001000',
#     '000000001100000',
#     '000000100001000',
#     '000000001000000',
#     '000000000100001',
#     '000000001010000',
#     '000000000001100',
#     '000000001001000',
#     '000000000000001',
#     '000000010001000'],
#    'bitstrings_energies': [-3.9200000000000017,
#     -3.0600000000000023,
#     -2.969999999999999,
#     -2.950000000000003,
#     -2.9200000000000017,
#     -2.9000000000000057,
#     -2.8799999999999955,
#     -2.8700000000000045,
#     -2.8100000000000023,
#     -2.7900000000000063],
#    'probabilities': [0.4229,
#     0.0115,
#     0.011,
#     0.0581,
#     0.009,
#     0.0058,
#     0.0094,
#     0.0302,
#     0.0358,
#     0.0104]}]]

# %% [markdown]
# ## Execution time comparison

# %% [markdown]
# This will show a function for each execution running. Each execution running is formed by the different maxfevs for which it was run.

# %%
times = []

for itr,result in enumerate(results):
    times.append([])
    for maxfev in maxfevs:
        times[itr].append(result['maxfev '+maxfev]['time'])

# write the functions
for itr,time in enumerate(times):
    plt.plot(maxfevs, time, label=file_names[itr])

# peronalize labels
plt.xlabel('maxfev')
plt.ylabel('time in seconds')
plt.title('Time required for optimizing')
plt.legend()

plt.show()

# %% [markdown]
# A clear advante in the use of GPU can be seen. For a reduced plot result, we can just calculate the 'speedup function' over the times.

# %% [markdown]
# ## approximate solutions probabilities comparison

# %% [markdown]
# For each execution running and maxfev, we will show the sum of ocurrance probabilities for the 10 most approximate solutions found.

# %%
probabilities = []
for itr,problem in enumerate(lowest_cost_bitstrings):
    probabilities.append([])
    for lcb in problem:
        probabilities[itr].append(sum(lcb['probabilities']))

for itr,probs in enumerate(probabilities):
    plt.plot(maxfevs, probs, label=file_names[itr])

# peronalize labels
plt.xlabel('maxfev')
plt.ylabel('probability')
plt.title('Probability of measuring the 10 most approximate solutions')
plt.legend()

plt.show()

# %% [markdown]
# In some way, a better probability performance trough giving more maxfevs can be seen. Of course, because QC is probabilitic, some stochastic behaviour is seen. But, in general terms, the occurance probability increase in a logical way.

# %% [markdown]
# ## Are all approximate solutions found feasible?

# %% [markdown]
# The next cell analyze for each (execution running,maxfev) if all the solutions found are feasible.

# %%
def is_feasible(bitstring):
    num_vacnJobs = 5
    
    for itr in range(0,len(bitstring),num_vacnJobs):
        sum = 0
        for i in range(itr,itr+num_vacnJobs):
            #print(bitstring[i])
            sum += int(bitstring[i])
        #print('res=',sum)
        if sum > 1:
            #print('sale')
            return False
    return True

for itr,problem in enumerate(lowest_cost_bitstrings):
    for itr2,lcb in enumerate(problem):
        feasible = True
        total_feasible_solutions = 0
        for solution_bitstring in lcb['solutions_bitstrings']:
            feasible = is_feasible(solution_bitstring)
            print('is_feasible(',file_names[itr],',',maxfevs[itr2],',',solution_bitstring,'):',feasible)
            if feasible:
                total_feasible_solutions += 1
        print('TOTAL FEASIBLE SOLUTIONS: ',total_feasible_solutions,'/10\n')
# Out:
# is_feasible( cpu_statevector , 100 , 000000000001000 ): True
# is_feasible( cpu_statevector , 100 , 000000001100000 ): False
# is_feasible( cpu_statevector , 100 , 000000100001000 ): True
# is_feasible( cpu_statevector , 100 , 000000001000000 ): True
# is_feasible( cpu_statevector , 100 , 000000000100001 ): True
# is_feasible( cpu_statevector , 100 , 000000001010000 ): True
# is_feasible( cpu_statevector , 100 , 000000000001100 ): False
# is_feasible( cpu_statevector , 100 , 000000001001000 ): True
# is_feasible( cpu_statevector , 100 , 000000000000001 ): True
# is_feasible( cpu_statevector , 100 , 000000010001000 ): True
# TOTAL FEASIBLE SOLUTIONS:  8 /10
#
# is_feasible( cpu_statevector , 250 , 000000000001000 ): True
# is_feasible( cpu_statevector , 250 , 000000001100000 ): False
# is_feasible( cpu_statevector , 250 , 000000100001000 ): True
# is_feasible( cpu_statevector , 250 , 000000001000000 ): True
# is_feasible( cpu_statevector , 250 , 000000000100001 ): True
# is_feasible( cpu_statevector , 250 , 000000001010000 ): True
# is_feasible( cpu_statevector , 250 , 000000000001100 ): False
# is_feasible( cpu_statevector , 250 , 000000001001000 ): True
# is_feasible( cpu_statevector , 250 , 000000000000001 ): True
# is_feasible( cpu_statevector , 250 , 000000010001000 ): True
# TOTAL FEASIBLE SOLUTIONS:  8 /10
#
# is_feasible( cpu_statevector , 500 , 000000000001000 ): True
# is_feasible( cpu_statevector , 500 , 000000001100000 ): False
# is_feasible( cpu_statevector , 500 , 000000100001000 ): True
# is_feasible( cpu_statevector , 500 , 000000001000000 ): True
# is_feasible( cpu_statevector , 500 , 000000000100001 ): True
# is_feasible( cpu_statevector , 500 , 000000001010000 ): True
# is_feasible( cpu_statevector , 500 , 000000000001100 ): False
# is_feasible( cpu_statevector , 500 , 000000001001000 ): True
# is_feasible( cpu_statevector , 500 , 000000000000001 ): True
# is_feasible( cpu_statevector , 500 , 000000010001000 ): True
# TOTAL FEASIBLE SOLUTIONS:  8 /10
#
# is_feasible( cpu_statevector , 750 , 000000000001000 ): True
# is_feasible( cpu_statevector , 750 , 000000001100000 ): False
# is_feasible( cpu_statevector , 750 , 000000100001000 ): True
# is_feasible( cpu_statevector , 750 , 000000001000000 ): True
# is_feasible( cpu_statevector , 750 , 000000000100001 ): True
# is_feasible( cpu_statevector , 750 , 000000001010000 ): True
# is_feasible( cpu_statevector , 750 , 000000000001100 ): False
# is_feasible( cpu_statevector , 750 , 000000001001000 ): True
# is_feasible( cpu_statevector , 750 , 000000000000001 ): True
# is_feasible( cpu_statevector , 750 , 000000010001000 ): True
# TOTAL FEASIBLE SOLUTIONS:  8 /10
#
# is_feasible( cpu_statevector , 1000 , 000000000001000 ): True
# is_feasible( cpu_statevector , 1000 , 000000001100000 ): False
# is_feasible( cpu_statevector , 1000 , 000000100001000 ): True
# is_feasible( cpu_statevector , 1000 , 000000001000000 ): True
# is_feasible( cpu_statevector , 1000 , 000000000100001 ): True
# is_feasible( cpu_statevector , 1000 , 000000001010000 ): True
# is_feasible( cpu_statevector , 1000 , 000000000001100 ): False
# is_feasible( cpu_statevector , 1000 , 000000001001000 ): True
# is_feasible( cpu_statevector , 1000 , 000000000000001 ): True
# is_feasible( cpu_statevector , 1000 , 000000010001000 ): True
# TOTAL FEASIBLE SOLUTIONS:  8 /10
#
# is_feasible( gpu_statevector , 100 , 000000000001000 ): True
# is_feasible( gpu_statevector , 100 , 000000001100000 ): False
# is_feasible( gpu_statevector , 100 , 000000100001000 ): True
# is_feasible( gpu_statevector , 100 , 000000001000000 ): True
# is_feasible( gpu_statevector , 100 , 000000000100001 ): True
# is_feasible( gpu_statevector , 100 , 000000001010000 ): True
# is_feasible( gpu_statevector , 100 , 000000000001100 ): False
# is_feasible( gpu_statevector , 100 , 000000001001000 ): True
# is_feasible( gpu_statevector , 100 , 000000000000001 ): True
# is_feasible( gpu_statevector , 100 , 000000010001000 ): True
# TOTAL FEASIBLE SOLUTIONS:  8 /10
#
# is_feasible( gpu_statevector , 250 , 000000000001000 ): True
# is_feasible( gpu_statevector , 250 , 000000001100000 ): False
# is_feasible( gpu_statevector , 250 , 000000100001000 ): True
# is_feasible( gpu_statevector , 250 , 000000001000000 ): True
# is_feasible( gpu_statevector , 250 , 000000000100001 ): True
# is_feasible( gpu_statevector , 250 , 000000001010000 ): True
# is_feasible( gpu_statevector , 250 , 000000000001100 ): False
# is_feasible( gpu_statevector , 250 , 000000001001000 ): True
# is_feasible( gpu_statevector , 250 , 000000000000001 ): True
# is_feasible( gpu_statevector , 250 , 000000010001000 ): True
# TOTAL FEASIBLE SOLUTIONS:  8 /10
#
# is_feasible( gpu_statevector , 500 , 000000000001000 ): True
# is_feasible( gpu_statevector , 500 , 000000001100000 ): False
# is_feasible( gpu_statevector , 500 , 000000100001000 ): True
# is_feasible( gpu_statevector , 500 , 000000001000000 ): True
# is_feasible( gpu_statevector , 500 , 000000000100001 ): True
# is_feasible( gpu_statevector , 500 , 000000001010000 ): True
# is_feasible( gpu_statevector , 500 , 000000000001100 ): False
# is_feasible( gpu_statevector , 500 , 000000001001000 ): True
# is_feasible( gpu_statevector , 500 , 000000000000001 ): True
# is_feasible( gpu_statevector , 500 , 000000010001000 ): True
# TOTAL FEASIBLE SOLUTIONS:  8 /10
#
# is_feasible( gpu_statevector , 750 , 000000000001000 ): True
# is_feasible( gpu_statevector , 750 , 000000001100000 ): False
# is_feasible( gpu_statevector , 750 , 000000100001000 ): True
# is_feasible( gpu_statevector , 750 , 000000001000000 ): True
# is_feasible( gpu_statevector , 750 , 000000000100001 ): True
# is_feasible( gpu_statevector , 750 , 000000001010000 ): True
# is_feasible( gpu_statevector , 750 , 000000000001100 ): False
# is_feasible( gpu_statevector , 750 , 000000001001000 ): True
# is_feasible( gpu_statevector , 750 , 000000000000001 ): True
# is_feasible( gpu_statevector , 750 , 000000010001000 ): True
# TOTAL FEASIBLE SOLUTIONS:  8 /10
#
# is_feasible( gpu_statevector , 1000 , 000000000001000 ): True
# is_feasible( gpu_statevector , 1000 , 000000001100000 ): False
# is_feasible( gpu_statevector , 1000 , 000000100001000 ): True
# is_feasible( gpu_statevector , 1000 , 000000001000000 ): True
# is_feasible( gpu_statevector , 1000 , 000000000100001 ): True
# is_feasible( gpu_statevector , 1000 , 000000001010000 ): True
# is_feasible( gpu_statevector , 1000 , 000000000001100 ): False
# is_feasible( gpu_statevector , 1000 , 000000001001000 ): True
# is_feasible( gpu_statevector , 1000 , 000000000000001 ): True
# is_feasible( gpu_statevector , 1000 , 000000010001000 ): True
# TOTAL FEASIBLE SOLUTIONS:  8 /10

# %% [markdown]
# In all the (execution_type,maxfev) configurations, there is a good number of feasible solutions in the most probable solutions. In particular, for all configurations there are 8/10 feasible solutions.

# %% [markdown]
# ## Cost histories comparison

# %%
for maxfev in maxfevs:
    fig, ax = plt.subplots()
    results[0]['maxfev '+maxfev]['result'].plot_cost(label='cpu_statevector',ax=ax)
    results[1]['maxfev '+maxfev]['result'].plot_cost(label='gpu_statevector',color='orange',ax=ax)
    ax.set_title('Cost history - maxfev '+maxfev)

# %% [markdown]
# For maxfev 100 cost histories, prety similar optimization happened.For max 250 cost histories, at the end, the gpu running find a better value. For maxfev 500, gpu running really get stuck in, probably, a local minimum at the fist 100 fevs. For maxfev 750, the cost histories are preety similar (a bit improvement for gpu). Same for maxfev 1000.

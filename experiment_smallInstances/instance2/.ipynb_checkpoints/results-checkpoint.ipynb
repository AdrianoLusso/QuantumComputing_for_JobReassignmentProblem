# %% [markdown]
# # Results for instance 2

# %% [markdown]
# This notebook shows the results over the previously experiments done

# %%
import json
import os
import matplotlib.pyplot as plt
from openqaoa.algorithms import QAOAResult
from openqaoa.qaoa_components import Hamiltonian,PauliOp
import numpy as np

# %% [markdown]
# ## Instance

# %%
with open('instance2.json', "r") as file:
    instance = json.load(file)
print('num_agents: ',instance['num_agents'])
print('num_vacnJobs: ',instance['num_vacnJobs'])
print('total amount of qubits: ',len(instance['allBinaryVariables']))
# Out:
# num_agents:  4
# num_vacnJobs:  5
# total amount of qubits:  20

# %% [markdown]
# ## Upload json files

# %%
results = []
file_names=['cpu_statevector','gpu_statevector']

for file_name in file_names:
    file_route = os.path.join('./',file_name+'.json')
    with open(file_route, "r") as file:
        result = json.load(file)
        #print(result)
        #result = QAOAResult.from_dict(result)
        results.append(result)

# %%
#results[0]

# %% [markdown]
# This is an important step. The data imported is in json format. For using the multiple analysis functions that OpenQAOA, we need to create the respective objects with the dict. For that we should:
#
# 1. Create the PauliOp objects for each cost hamiltonian
# 2. Once we have the PauliOp objects, we create each Hamiltonian object
# 3. Once we have the Hamiltonian object, we create the QAOAResult obejct

# %%
maxfevs=['100','250','500','750','1000']
for itr,result in enumerate(results):
    for maxfev in maxfevs:
        # get the QAOA result as dict
        result_dict = results[itr]['maxfev '+maxfev]['result']

        # get cost hamiltonian as dict
        hamiltonian_dict = result_dict['cost_hamiltonian']

        # for each pauliOp represented as dict, convert it to an object
        for itr2,pauliOp_dict in enumerate(hamiltonian_dict['terms']):
            qubit_indices = pauliOp_dict['qubit_indices']
            pauli_str = pauliOp_dict['pauli_str']

            hamiltonian_dict['terms'][itr2] = PauliOp(pauli_str,qubit_indices)

        # now that we have PauliOp objects, we can create the Hamiltonian object for the cost hamiltonian
        result_dict['cost_hamiltonian'] = Hamiltonian(hamiltonian_dict['terms'],hamiltonian_dict['coeffs'],hamiltonian_dict['constant']) 

        # now that we have the Hamiltonian object, we can create que QAOAResult object
        results[itr]['maxfev '+maxfev]['result'] = QAOAResult.from_dict(result_dict)

# %% [markdown]
# One that we have the QAOAResult object, we can make use of a useful function called  $\texttt{lowest\_cost\_bitstrings(n)}$ . This return the $n$ most approximates solutions found by the QAOA optimization. For each one, it show the respective bitstring, its energy(cost) and it occurance probability.
#
# Here, it is important to notice that, if the QAOA is not correctly configured, $\textbf{the most approximates solutions found will be bad solutions by nature}$. Remember that this function just analyze the solutions found by the QAOA optimization, not the whole search space. That means, if an optimal solution is not found by the QAOA optimization, this function will not show it.
#
# For this notebook, we will took the 10 most approximates solutions found.

# %%
lowest_cost_bitstrings = []
for itr,result in enumerate(results):
    lowest_cost_bitstrings.append([])
    for maxfev in maxfevs:
        #lowest_cost_bitstrings = result['maxfev '+maxfev]['result'].lowest_cost_bitstrings(10)
       # probabilities.append(
        #    lowest_cost_bitstrings
       # )
        lowest_cost_bitstrings[itr].append(result['maxfev '+maxfev]['result'].lowest_cost_bitstrings(10))

# %%
lowest_cost_bitstrings
# Out:
# [[{'solutions_bitstrings': ['00000000010010000000',
#     '00000000100001000000',
#     '00000001010010000000',
#     '00000001100001000000',
#     '00001000000101000000',
#     '00000000000110000000',
#     '00001000010000010000',
#     '00000010010010000000',
#     '00000000100000010000',
#     '00001000000001000000'],
#    'bitstrings_energies': [-5.150000000000006,
#     -5.060000000000002,
#     -4.469999999999999,
#     -4.38000000000001,
#     -4.290000000000006,
#     -4.280000000000001,
#     -4.25,
#     -4.180000000000007,
#     -4.150000000000006,
#     -4.140000000000015],
#    'probabilities': [0.1063,
#     0.0847,
#     0.0047,
#     0.0034,
#     0.0016,
#     0.0198,
#     0.0033,
#     0.0015,
#     0.0126,
#     0.0038]},
#   {'solutions_bitstrings': ['00000000010010000000',
#     '00000000100001000000',
#     '00000001010010000000',
#     '00000001100001000000',
#     '00001000000101000000',
#     '00000000000110000000',
#     '00001000010000010000',
#     '00000010010010000000',
#     '00000000100000010000',
#     '00001000000001000000'],
#    'bitstrings_energies': [-5.150000000000006,
#     -5.060000000000002,
#     -4.469999999999999,
#     -4.38000000000001,
#     -4.290000000000006,
#     -4.280000000000001,
#     -4.25,
#     -4.180000000000007,
#     -4.150000000000006,
#     -4.140000000000015],
#    'probabilities': [0.1366,
#     0.1078,
#     0.003,
#     0.002,
#     0.0043,
#     0.0209,
#     0.0046,
#     0.0013,
#     0.017,
#     0.0136]},
#   {'solutions_bitstrings': ['00000000010010000000',
#     '00000000100001000000',
#     '00000001010010000000',
#     '00000001100001000000',
#     '00001000000101000000',
#     '00000000000110000000',
#     '00001000010000010000',
#     '00000010010010000000',
#     '00000000100000010000',
#     '00001000000001000000'],
#    'bitstrings_energies': [-5.150000000000006,
#     -5.060000000000002,
#     -4.469999999999999,
#     -4.38000000000001,
#     -4.290000000000006,
#     -4.280000000000001,
#     -4.25,
#     -4.180000000000007,
#     -4.150000000000006,
#     -4.140000000000015],
#    'probabilities': [0.1464,
#     0.1161,
#     0.0006,
#     0.0004,
#     0.0017,
#     0.013,
#     0.0017,
#     0.0011,
#     0.0092,
#     0.0237]},
#   {'solutions_bitstrings': ['00000000010010000000',
#     '00000000100001000000',
#     '00000001010010000000',
#     '00000001100001000000',
#     '00001000000101000000',
#     '00000000000110000000',
#     '00001000010000010000',
#     '00000010010010000000',
#     '00000000100000010000',
#     '00001000000001000000'],
#    'bitstrings_energies': [-5.150000000000006,
#     -5.060000000000002,
#     -4.469999999999999,
#     -4.38000000000001,
#     -4.290000000000006,
#     -4.280000000000001,
#     -4.25,
#     -4.180000000000007,
#     -4.150000000000006,
#     -4.140000000000015],
#    'probabilities': [0.1447,
#     0.114,
#     0.0026,
#     0.0033,
#     0.0022,
#     0.0151,
#     0.0021,
#     0.0009,
#     0.0107,
#     0.0149]},
#   {'solutions_bitstrings': ['00000000010010000000',
#     '00000000100001000000',
#     '00000001010010000000',
#     '00000001100001000000',
#     '00001000000101000000',
#     '00000000000110000000',
#     '00001000010000010000',
#     '00000010010010000000',
#     '00000000100000010000',
#     '00001000000001000000'],
#    'bitstrings_energies': [-5.150000000000006,
#     -5.060000000000002,
#     -4.469999999999999,
#     -4.38000000000001,
#     -4.290000000000006,
#     -4.280000000000001,
#     -4.25,
#     -4.180000000000007,
#     -4.150000000000006,
#     -4.140000000000015],
#    'probabilities': [0.1381,
#     0.114,
#     0.0012,
#     0.0018,
#     0.0031,
#     0.0161,
#     0.003,
#     0.002,
#     0.0109,
#     0.0146]}],
#  [{'solutions_bitstrings': ['00000000010010000000',
#     '00000000100001000000',
#     '00000001010010000000',
#     '00000001100001000000',
#     '00001000000101000000',
#     '00000000000110000000',
#     '00001000010000010000',
#     '00000010010010000000',
#     '00000000100000010000',
#     '00001000000001000000'],
#    'bitstrings_energies': [-5.150000000000006,
#     -5.060000000000002,
#     -4.469999999999999,
#     -4.38000000000001,
#     -4.290000000000006,
#     -4.280000000000001,
#     -4.25,
#     -4.180000000000007,
#     -4.150000000000006,
#     -4.140000000000015],
#    'probabilities': [0.1029,
#     0.0814,
#     0.0057,
#     0.003,
#     0.002,
#     0.0204,
#     0.003,
#     0.0022,
#     0.0138,
#     0.004]},
#   {'solutions_bitstrings': ['00000000010010000000',
#     '00000000100001000000',
#     '00000001010010000000',
#     '00000001100001000000',
#     '00001000000101000000',
#     '00000000000110000000',
#     '00001000010000010000',
#     '00000010010010000000',
#     '00000000100000010000',
#     '00001000000001000000'],
#    'bitstrings_energies': [-5.150000000000006,
#     -5.060000000000002,
#     -4.469999999999999,
#     -4.38000000000001,
#     -4.290000000000006,
#     -4.280000000000001,
#     -4.25,
#     -4.180000000000007,
#     -4.150000000000006,
#     -4.140000000000015],
#    'probabilities': [0.1248,
#     0.1024,
#     0.003,
#     0.0025,
#     0.0043,
#     0.0232,
#     0.0037,
#     0.0001,
#     0.0158,
#     0.0142]},
#   {'solutions_bitstrings': ['00000000010010000000',
#     '00000000100001000000',
#     '00000001010010000000',
#     '00000001100001000000',
#     '00001000000101000000',
#     '00000000000110000000',
#     '00001000010000010000',
#     '00000010010010000000',
#     '00000000100000010000',
#     '00001000000001000000'],
#    'bitstrings_energies': [-5.150000000000006,
#     -5.060000000000002,
#     -4.469999999999999,
#     -4.38000000000001,
#     -4.290000000000006,
#     -4.280000000000001,
#     -4.25,
#     -4.180000000000007,
#     -4.150000000000006,
#     -4.140000000000015],
#    'probabilities': [0.1272,
#     0.0954,
#     0.0043,
#     0.003,
#     0.0029,
#     0.0193,
#     0.0026,
#     0.0013,
#     0.0113,
#     0.0076]},
#   {'solutions_bitstrings': ['00000000010010000000',
#     '00000000100001000000',
#     '00000001010010000000',
#     '00000001100001000000',
#     '00001000000101000000',
#     '00000000000110000000',
#     '00001000010000010000',
#     '00000010010010000000',
#     '00000000100000010000',
#     '00001000000001000000'],
#    'bitstrings_energies': [-5.150000000000006,
#     -5.060000000000002,
#     -4.469999999999999,
#     -4.38000000000001,
#     -4.290000000000006,
#     -4.280000000000001,
#     -4.25,
#     -4.180000000000007,
#     -4.150000000000006,
#     -4.140000000000015],
#    'probabilities': [0.1262,
#     0.0991,
#     0.0043,
#     0.0025,
#     0.003,
#     0.018,
#     0.0026,
#     0.0009,
#     0.0103,
#     0.0084]},
#   {'solutions_bitstrings': ['00000000010010000000',
#     '00000000100001000000',
#     '00000001010010000000',
#     '00000001100001000000',
#     '00001000000101000000',
#     '00000000000110000000',
#     '00001000010000010000',
#     '00000010010010000000',
#     '00000000100000010000',
#     '00001000000001000000'],
#    'bitstrings_energies': [-5.150000000000006,
#     -5.060000000000002,
#     -4.469999999999999,
#     -4.38000000000001,
#     -4.290000000000006,
#     -4.280000000000001,
#     -4.25,
#     -4.180000000000007,
#     -4.150000000000006,
#     -4.140000000000015],
#    'probabilities': [0.1822,
#     0.1546,
#     0.0057,
#     0.0045,
#     0.0036,
#     0.0232,
#     0.0059,
#     0.0027,
#     0.0162,
#     0.0139]}]]

# %% [markdown]
# ## Execution time comparison

# %% [markdown]
# This will show a function for each execution running. Each execution running is formed by the different maxfevs for which it was run.

# %%
times = []

for itr,result in enumerate(results):
    times.append([])
    for maxfev in maxfevs:
        times[itr].append(result['maxfev '+maxfev]['time'])

# write the functions
for itr,time in enumerate(times):
    plt.plot(maxfevs, time, label=file_names[itr])

# peronalize labels
plt.xlabel('maxfev')
plt.ylabel('time in seconds')
plt.title('Time required for optimizing instance 0')
plt.legend()

plt.show()

# %% [markdown]
# cpu_statevector time function keep an expected linear evolution. But gpu_statevector starts with an linea evolution from 100 to 750, and having a substantial decrease for 1000 maxfev. This kind of courious, it will be interesting discovering if it has deterministic reason.

# %% [markdown]
# ## approximate solutions probabilities comparison

# %% [markdown]
# For each execution running and maxfev, we will show the sum of ocurrance probabilities for the 10 most approximate solutions found.

# %%
probabilities = []
for itr,problem in enumerate(lowest_cost_bitstrings):
    probabilities.append([])
    for lcb in problem:
        probabilities[itr].append(sum(lcb['probabilities']))

for itr,probs in enumerate(probabilities):
    plt.plot(maxfevs, probs, label=file_names[itr])

# peronalize labels
plt.xlabel('maxfev')
plt.ylabel('probability')
plt.title('Probability of measuring the 10 most approximate solutions')
plt.legend()

plt.show()

# %% [markdown]
# In general, such bad results in probability of measuring 10 most approximate solutions found. Specially, for cpu_statevector. gpu_statevector found a way to achieves for 1000 fevs.
#
# I think about two possible reason for this:
#
# * a particular instance which doesn't work prety well for the algorithms
# * Because the problem size starts to increase, a bigger number of fevs is needed.

# %% [markdown]
# ## Are all approximate solutions found feasible?

# %% [markdown]
# The next cell analyze for each (execution running,maxfev) if all the solutions found are feasible.

# %%
num_vacnJobs = 5

def insertar_espacios(cadena, n):
    resultado = [cadena[i:i+n] for i in range(0, len(cadena), n)]
    return ' '.join(resultado)
    
def is_feasible(bitstring):
    global num_vacnJobs
    vacnJob_assigned = [0 for i in range(num_vacnJobs)]
    
    for itr in range(0,len(bitstring),num_vacnJobs):
        sum = 0
        for i in range(itr,itr+num_vacnJobs):
            #print(bitstring[i])
            sum += int(bitstring[i])
            if int(bitstring[i]) == 1:
                if vacnJob_assigned[i % num_vacnJobs] == 1:
                    return False
                else:
                    vacnJob_assigned[i % num_vacnJobs] = 1
        #print('res=',sum)
        if sum > 1:
            #print('sale')
            return False
    return True

for itr,problem in enumerate(lowest_cost_bitstrings):
    for itr2,lcb in enumerate(problem):
        feasible = True
        total_feasible_solutions = 0
        for solution_bitstring in lcb['solutions_bitstrings']:
            feasible = is_feasible(solution_bitstring)
            print('is_feasible(',file_names[itr],',',maxfevs[itr2],',',insertar_espacios(solution_bitstring,num_vacnJobs),'):',feasible)
            if feasible:
                total_feasible_solutions += 1
        print('TOTAL FEASIBLE SOLUTIONS: ',total_feasible_solutions,'/10\n')
# Out:
# is_feasible( cpu_statevector , 100 , 00000 00001 00100 00000 ): True
# is_feasible( cpu_statevector , 100 , 00000 00010 00010 00000 ): False
# is_feasible( cpu_statevector , 100 , 00000 00101 00100 00000 ): False
# is_feasible( cpu_statevector , 100 , 00000 00110 00010 00000 ): False
# is_feasible( cpu_statevector , 100 , 00001 00000 01010 00000 ): False
# is_feasible( cpu_statevector , 100 , 00000 00000 01100 00000 ): False
# is_feasible( cpu_statevector , 100 , 00001 00001 00000 10000 ): False
# is_feasible( cpu_statevector , 100 , 00000 01001 00100 00000 ): False
# is_feasible( cpu_statevector , 100 , 00000 00010 00000 10000 ): True
# is_feasible( cpu_statevector , 100 , 00001 00000 00010 00000 ): True
# TOTAL FEASIBLE SOLUTIONS:  3 /10
#
# is_feasible( cpu_statevector , 250 , 00000 00001 00100 00000 ): True
# is_feasible( cpu_statevector , 250 , 00000 00010 00010 00000 ): False
# is_feasible( cpu_statevector , 250 , 00000 00101 00100 00000 ): False
# is_feasible( cpu_statevector , 250 , 00000 00110 00010 00000 ): False
# is_feasible( cpu_statevector , 250 , 00001 00000 01010 00000 ): False
# is_feasible( cpu_statevector , 250 , 00000 00000 01100 00000 ): False
# is_feasible( cpu_statevector , 250 , 00001 00001 00000 10000 ): False
# is_feasible( cpu_statevector , 250 , 00000 01001 00100 00000 ): False
# is_feasible( cpu_statevector , 250 , 00000 00010 00000 10000 ): True
# is_feasible( cpu_statevector , 250 , 00001 00000 00010 00000 ): True
# TOTAL FEASIBLE SOLUTIONS:  3 /10
#
# is_feasible( cpu_statevector , 500 , 00000 00001 00100 00000 ): True
# is_feasible( cpu_statevector , 500 , 00000 00010 00010 00000 ): False
# is_feasible( cpu_statevector , 500 , 00000 00101 00100 00000 ): False
# is_feasible( cpu_statevector , 500 , 00000 00110 00010 00000 ): False
# is_feasible( cpu_statevector , 500 , 00001 00000 01010 00000 ): False
# is_feasible( cpu_statevector , 500 , 00000 00000 01100 00000 ): False
# is_feasible( cpu_statevector , 500 , 00001 00001 00000 10000 ): False
# is_feasible( cpu_statevector , 500 , 00000 01001 00100 00000 ): False
# is_feasible( cpu_statevector , 500 , 00000 00010 00000 10000 ): True
# is_feasible( cpu_statevector , 500 , 00001 00000 00010 00000 ): True
# TOTAL FEASIBLE SOLUTIONS:  3 /10
#
# is_feasible( cpu_statevector , 750 , 00000 00001 00100 00000 ): True
# is_feasible( cpu_statevector , 750 , 00000 00010 00010 00000 ): False
# is_feasible( cpu_statevector , 750 , 00000 00101 00100 00000 ): False
# is_feasible( cpu_statevector , 750 , 00000 00110 00010 00000 ): False
# is_feasible( cpu_statevector , 750 , 00001 00000 01010 00000 ): False
# is_feasible( cpu_statevector , 750 , 00000 00000 01100 00000 ): False
# is_feasible( cpu_statevector , 750 , 00001 00001 00000 10000 ): False
# is_feasible( cpu_statevector , 750 , 00000 01001 00100 00000 ): False
# is_feasible( cpu_statevector , 750 , 00000 00010 00000 10000 ): True
# is_feasible( cpu_statevector , 750 , 00001 00000 00010 00000 ): True
# TOTAL FEASIBLE SOLUTIONS:  3 /10
#
# is_feasible( cpu_statevector , 1000 , 00000 00001 00100 00000 ): True
# is_feasible( cpu_statevector , 1000 , 00000 00010 00010 00000 ): False
# is_feasible( cpu_statevector , 1000 , 00000 00101 00100 00000 ): False
# is_feasible( cpu_statevector , 1000 , 00000 00110 00010 00000 ): False
# is_feasible( cpu_statevector , 1000 , 00001 00000 01010 00000 ): False
# is_feasible( cpu_statevector , 1000 , 00000 00000 01100 00000 ): False
# is_feasible( cpu_statevector , 1000 , 00001 00001 00000 10000 ): False
# is_feasible( cpu_statevector , 1000 , 00000 01001 00100 00000 ): False
# is_feasible( cpu_statevector , 1000 , 00000 00010 00000 10000 ): True
# is_feasible( cpu_statevector , 1000 , 00001 00000 00010 00000 ): True
# TOTAL FEASIBLE SOLUTIONS:  3 /10
#
# is_feasible( gpu_statevector , 100 , 00000 00001 00100 00000 ): True
# is_feasible( gpu_statevector , 100 , 00000 00010 00010 00000 ): False
# is_feasible( gpu_statevector , 100 , 00000 00101 00100 00000 ): False
# is_feasible( gpu_statevector , 100 , 00000 00110 00010 00000 ): False
# is_feasible( gpu_statevector , 100 , 00001 00000 01010 00000 ): False
# is_feasible( gpu_statevector , 100 , 00000 00000 01100 00000 ): False
# is_feasible( gpu_statevector , 100 , 00001 00001 00000 10000 ): False
# is_feasible( gpu_statevector , 100 , 00000 01001 00100 00000 ): False
# is_feasible( gpu_statevector , 100 , 00000 00010 00000 10000 ): True
# is_feasible( gpu_statevector , 100 , 00001 00000 00010 00000 ): True
# TOTAL FEASIBLE SOLUTIONS:  3 /10
#
# is_feasible( gpu_statevector , 250 , 00000 00001 00100 00000 ): True
# is_feasible( gpu_statevector , 250 , 00000 00010 00010 00000 ): False
# is_feasible( gpu_statevector , 250 , 00000 00101 00100 00000 ): False
# is_feasible( gpu_statevector , 250 , 00000 00110 00010 00000 ): False
# is_feasible( gpu_statevector , 250 , 00001 00000 01010 00000 ): False
# is_feasible( gpu_statevector , 250 , 00000 00000 01100 00000 ): False
# is_feasible( gpu_statevector , 250 , 00001 00001 00000 10000 ): False
# is_feasible( gpu_statevector , 250 , 00000 01001 00100 00000 ): False
# is_feasible( gpu_statevector , 250 , 00000 00010 00000 10000 ): True
# is_feasible( gpu_statevector , 250 , 00001 00000 00010 00000 ): True
# TOTAL FEASIBLE SOLUTIONS:  3 /10
#
# is_feasible( gpu_statevector , 500 , 00000 00001 00100 00000 ): True
# is_feasible( gpu_statevector , 500 , 00000 00010 00010 00000 ): False
# is_feasible( gpu_statevector , 500 , 00000 00101 00100 00000 ): False
# is_feasible( gpu_statevector , 500 , 00000 00110 00010 00000 ): False
# is_feasible( gpu_statevector , 500 , 00001 00000 01010 00000 ): False
# is_feasible( gpu_statevector , 500 , 00000 00000 01100 00000 ): False
# is_feasible( gpu_statevector , 500 , 00001 00001 00000 10000 ): False
# is_feasible( gpu_statevector , 500 , 00000 01001 00100 00000 ): False
# is_feasible( gpu_statevector , 500 , 00000 00010 00000 10000 ): True
# is_feasible( gpu_statevector , 500 , 00001 00000 00010 00000 ): True
# TOTAL FEASIBLE SOLUTIONS:  3 /10
#
# is_feasible( gpu_statevector , 750 , 00000 00001 00100 00000 ): True
# is_feasible( gpu_statevector , 750 , 00000 00010 00010 00000 ): False
# is_feasible( gpu_statevector , 750 , 00000 00101 00100 00000 ): False
# is_feasible( gpu_statevector , 750 , 00000 00110 00010 00000 ): False
# is_feasible( gpu_statevector , 750 , 00001 00000 01010 00000 ): False
# is_feasible( gpu_statevector , 750 , 00000 00000 01100 00000 ): False
# is_feasible( gpu_statevector , 750 , 00001 00001 00000 10000 ): False
# is_feasible( gpu_statevector , 750 , 00000 01001 00100 00000 ): False
# is_feasible( gpu_statevector , 750 , 00000 00010 00000 10000 ): True
# is_feasible( gpu_statevector , 750 , 00001 00000 00010 00000 ): True
# TOTAL FEASIBLE SOLUTIONS:  3 /10
#
# is_feasible( gpu_statevector , 1000 , 00000 00001 00100 00000 ): True
# is_feasible( gpu_statevector , 1000 , 00000 00010 00010 00000 ): False
# is_feasible( gpu_statevector , 1000 , 00000 00101 00100 00000 ): False
# is_feasible( gpu_statevector , 1000 , 00000 00110 00010 00000 ): False
# is_feasible( gpu_statevector , 1000 , 00001 00000 01010 00000 ): False
# is_feasible( gpu_statevector , 1000 , 00000 00000 01100 00000 ): False
# is_feasible( gpu_statevector , 1000 , 00001 00001 00000 10000 ): False
# is_feasible( gpu_statevector , 1000 , 00000 01001 00100 00000 ): False
# is_feasible( gpu_statevector , 1000 , 00000 00010 00000 10000 ): True
# is_feasible( gpu_statevector , 1000 , 00001 00000 00010 00000 ): True
# TOTAL FEASIBLE SOLUTIONS:  3 /10

# %% [markdown]
# As it could be supposed from last section, there really bad results for the total feasible solutions.

# %% [markdown]
# ## Cost histories comparison

# %%
for maxfev in maxfevs:
    fig, ax = plt.subplots()
    results[0]['maxfev '+maxfev]['result'].plot_cost(label='cpu_statevector',ax=ax)
    results[1]['maxfev '+maxfev]['result'].plot_cost(label='gpu_statevector',color='orange',ax=ax)
    ax.set_title('Cost history - maxfev '+maxfev)

# %% [markdown]
# For maxfev 100 cost history, the optimization is pretty similar. Also for 250 maxfev, but with some outperforming from gpu over most of the optimization. For maxfev 500 an 750, around fev 150, cpu running completely starts outperforming the fpu running. The gpu running stucks in a local minimum. For maxfev 1000, gpu running is the one which outperform since aprox. fev 350.

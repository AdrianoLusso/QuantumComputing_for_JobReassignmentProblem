# %% [markdown]
# # Results for instance 1

# %% [markdown]
# This notebook shows the results over the previously experiments done

# %%
import json
import os
import matplotlib.pyplot as plt
from openqaoa.algorithms import QAOAResult
from openqaoa.qaoa_components import Hamiltonian,PauliOp
import numpy as np

# %% [markdown]
# ## Upload json files

# %%
results = []
file_names=['cpu_statevector','gpu_statevector']

for file_name in file_names:
    file_route = os.path.join('./',file_name+'.json')
    with open(file_route, "r") as file:
        result = json.load(file)
        #print(result)
        #result = QAOAResult.from_dict(result)
        results.append(result)

# %%
#results[0]

# %% [markdown]
# This is an important step. The data imported is in json format. For using the multiple analysis functions that OpenQAOA, we need to create the respective objects with the dict. For that we should:
#
# 1. Create the PauliOp objects for each cost hamiltonian
# 2. Once we have the PauliOp objects, we create each Hamiltonian object
# 3. Once we have the Hamiltonian object, we create the QAOAResult obejct

# %%
maxfevs=['100','250','500','750','1000']
for itr,result in enumerate(results):
    for maxfev in maxfevs:
        # get the QAOA result as dict
        result_dict = results[itr]['maxfev '+maxfev]['result']

        # get cost hamiltonian as dict
        hamiltonian_dict = result_dict['cost_hamiltonian']

        # for each pauliOp represented as dict, convert it to an object
        for itr2,pauliOp_dict in enumerate(hamiltonian_dict['terms']):
            qubit_indices = pauliOp_dict['qubit_indices']
            pauli_str = pauliOp_dict['pauli_str']

            hamiltonian_dict['terms'][itr2] = PauliOp(pauli_str,qubit_indices)

        # now that we have PauliOp objects, we can create the Hamiltonian object for the cost hamiltonian
        result_dict['cost_hamiltonian'] = Hamiltonian(hamiltonian_dict['terms'],hamiltonian_dict['coeffs'],hamiltonian_dict['constant']) 

        # now that we have the Hamiltonian object, we can create que QAOAResult object
        results[itr]['maxfev '+maxfev]['result'] = QAOAResult.from_dict(result_dict)

# %% [markdown]
# One that we have the QAOAResult object, we can make use of a useful function called  $\texttt{lowest\_cost\_bitstrings(n)}$ . This return the $n$ most approximates solutions found by the QAOA optimization. For each one, it show the respective bitstring, its energy(cost) and it occurance probability.
#
# Here, it is important to notice that, if the QAOA is not correctly configured, $\textbf{the most approximates solutions found will be bad solutions by nature}$. Remember that this function just analyze the solutions found by the QAOA optimization, not the whole search space. That means, if an optimal solution is not found by the QAOA optimization, this function will not show it.
#
# For this notebook, we will took the 10 most approximates solutions found.

# %%
lowest_cost_bitstrings = []
for itr,result in enumerate(results):
    lowest_cost_bitstrings.append([])
    for maxfev in maxfevs:
        #lowest_cost_bitstrings = result['maxfev '+maxfev]['result'].lowest_cost_bitstrings(10)
       # probabilities.append(
        #    lowest_cost_bitstrings
       # )
        lowest_cost_bitstrings[itr].append(result['maxfev '+maxfev]['result'].lowest_cost_bitstrings(10))

# %%
lowest_cost_bitstrings
# Out:
# [[{'solutions_bitstrings': ['000001010000000000',
#     '000001000000010000',
#     '000001010000100000',
#     '000100010000001000',
#     '000001100000010000',
#     '000000010000001000',
#     '000100001000010000',
#     '000010000000001000',
#     '000000001000010000',
#     '000010001000000000'],
#    'bitstrings_energies': [-3.9399999999999977,
#     -3.8599999999999994,
#     -3.789999999999992,
#     -3.719999999999999,
#     -3.6700000000000017,
#     -3.569999999999993,
#     -3.530000000000001,
#     -3.430000000000007,
#     -3.3800000000000097,
#     -3.319999999999993],
#    'probabilities': [0.0677,
#     0.0583,
#     0.0113,
#     0.0123,
#     0.0096,
#     0.0343,
#     0.0101,
#     0.0275,
#     0.0238,
#     0.0196]},
#   {'solutions_bitstrings': ['000001010000000000',
#     '000001000000010000',
#     '000001010000100000',
#     '000100010000001000',
#     '000001100000010000',
#     '000000010000001000',
#     '000100001000010000',
#     '000010000000001000',
#     '000000001000010000',
#     '000010001000000000'],
#    'bitstrings_energies': [-3.9399999999999977,
#     -3.8599999999999994,
#     -3.789999999999992,
#     -3.719999999999999,
#     -3.6700000000000017,
#     -3.569999999999993,
#     -3.530000000000001,
#     -3.430000000000007,
#     -3.3800000000000097,
#     -3.319999999999993],
#    'probabilities': [0.0897,
#     0.0783,
#     0.0138,
#     0.0173,
#     0.0117,
#     0.0437,
#     0.0119,
#     0.0372,
#     0.0298,
#     0.0309]},
#   {'solutions_bitstrings': ['000001010000000000',
#     '000001000000010000',
#     '000001010000100000',
#     '000100010000001000',
#     '000001100000010000',
#     '000000010000001000',
#     '000100001000010000',
#     '000010000000001000',
#     '000000001000010000',
#     '000010001000000000'],
#    'bitstrings_energies': [-3.9399999999999977,
#     -3.8599999999999994,
#     -3.789999999999992,
#     -3.719999999999999,
#     -3.6700000000000017,
#     -3.569999999999993,
#     -3.530000000000001,
#     -3.430000000000007,
#     -3.3800000000000097,
#     -3.319999999999993],
#    'probabilities': [0.1095,
#     0.0885,
#     0.0206,
#     0.0224,
#     0.0141,
#     0.046,
#     0.0141,
#     0.0443,
#     0.0327,
#     0.0362]},
#   {'solutions_bitstrings': ['000001010000000000',
#     '000001000000010000',
#     '000001010000100000',
#     '000100010000001000',
#     '000001100000010000',
#     '000000010000001000',
#     '000100001000010000',
#     '000010000000001000',
#     '000000001000010000',
#     '000010001000000000'],
#    'bitstrings_energies': [-3.9399999999999977,
#     -3.8599999999999994,
#     -3.789999999999992,
#     -3.719999999999999,
#     -3.6700000000000017,
#     -3.569999999999993,
#     -3.530000000000001,
#     -3.430000000000007,
#     -3.3800000000000097,
#     -3.319999999999993],
#    'probabilities': [0.109,
#     0.0902,
#     0.0194,
#     0.0251,
#     0.0166,
#     0.0483,
#     0.0171,
#     0.0474,
#     0.0342,
#     0.0376]},
#   {'solutions_bitstrings': ['000001010000000000',
#     '000001000000010000',
#     '000001010000100000',
#     '000100010000001000',
#     '000001100000010000',
#     '000000010000001000',
#     '000100001000010000',
#     '000010000000001000',
#     '000000001000010000',
#     '000010001000000000'],
#    'bitstrings_energies': [-3.9399999999999977,
#     -3.8599999999999994,
#     -3.789999999999992,
#     -3.719999999999999,
#     -3.6700000000000017,
#     -3.569999999999993,
#     -3.530000000000001,
#     -3.430000000000007,
#     -3.3800000000000097,
#     -3.319999999999993],
#    'probabilities': [0.1117,
#     0.0947,
#     0.0129,
#     0.018,
#     0.0104,
#     0.0566,
#     0.0128,
#     0.0488,
#     0.0391,
#     0.0377]}],
#  [{'solutions_bitstrings': ['000001010000000000',
#     '000001000000010000',
#     '000001010000100000',
#     '000100010000001000',
#     '000001100000010000',
#     '000000010000001000',
#     '000100001000010000',
#     '000010000000001000',
#     '000000001000010000',
#     '000010001000000000'],
#    'bitstrings_energies': [-3.9399999999999977,
#     -3.8599999999999994,
#     -3.789999999999992,
#     -3.719999999999999,
#     -3.6700000000000017,
#     -3.569999999999993,
#     -3.530000000000001,
#     -3.430000000000007,
#     -3.3800000000000097,
#     -3.319999999999993],
#    'probabilities': [0.068,
#     0.0583,
#     0.0132,
#     0.0137,
#     0.0092,
#     0.0323,
#     0.0097,
#     0.031,
#     0.0252,
#     0.0225]},
#   {'solutions_bitstrings': ['000001010000000000',
#     '000001000000010000',
#     '000001010000100000',
#     '000100010000001000',
#     '000001100000010000',
#     '000000010000001000',
#     '000100001000010000',
#     '000010000000001000',
#     '000000001000010000',
#     '000010001000000000'],
#    'bitstrings_energies': [-3.9399999999999977,
#     -3.8599999999999994,
#     -3.789999999999992,
#     -3.719999999999999,
#     -3.6700000000000017,
#     -3.569999999999993,
#     -3.530000000000001,
#     -3.430000000000007,
#     -3.3800000000000097,
#     -3.319999999999993],
#    'probabilities': [0.0917,
#     0.0783,
#     0.0112,
#     0.0173,
#     0.0105,
#     0.0454,
#     0.009,
#     0.0381,
#     0.0279,
#     0.0283]},
#   {'solutions_bitstrings': ['000001010000000000',
#     '000001000000010000',
#     '000001010000100000',
#     '000100010000001000',
#     '000001100000010000',
#     '000000010000001000',
#     '000100001000010000',
#     '000010000000001000',
#     '000000001000010000',
#     '000010001000000000'],
#    'bitstrings_energies': [-3.9399999999999977,
#     -3.8599999999999994,
#     -3.789999999999992,
#     -3.719999999999999,
#     -3.6700000000000017,
#     -3.569999999999993,
#     -3.530000000000001,
#     -3.430000000000007,
#     -3.3800000000000097,
#     -3.319999999999993],
#    'probabilities': [0.1114,
#     0.1038,
#     0.0141,
#     0.018,
#     0.0107,
#     0.0475,
#     0.0126,
#     0.048,
#     0.0355,
#     0.0384]},
#   {'solutions_bitstrings': ['000001010000000000',
#     '000001000000010000',
#     '000001010000100000',
#     '000100010000001000',
#     '000001100000010000',
#     '000000010000001000',
#     '000100001000010000',
#     '000010000000001000',
#     '000000001000010000',
#     '000010001000000000'],
#    'bitstrings_energies': [-3.9399999999999977,
#     -3.8599999999999994,
#     -3.789999999999992,
#     -3.719999999999999,
#     -3.6700000000000017,
#     -3.569999999999993,
#     -3.530000000000001,
#     -3.430000000000007,
#     -3.3800000000000097,
#     -3.319999999999993],
#    'probabilities': [0.0844,
#     0.0778,
#     0.0124,
#     0.0161,
#     0.0112,
#     0.0465,
#     0.0158,
#     0.046,
#     0.0329,
#     0.0349]},
#   {'solutions_bitstrings': ['000001010000000000',
#     '000001000000010000',
#     '000001010000100000',
#     '000100010000001000',
#     '000001100000010000',
#     '000000010000001000',
#     '000100001000010000',
#     '000010000000001000',
#     '000000001000010000',
#     '000010001000000000'],
#    'bitstrings_energies': [-3.9399999999999977,
#     -3.8599999999999994,
#     -3.789999999999992,
#     -3.719999999999999,
#     -3.6700000000000017,
#     -3.569999999999993,
#     -3.530000000000001,
#     -3.430000000000007,
#     -3.3800000000000097,
#     -3.319999999999993],
#    'probabilities': [0.1067,
#     0.0888,
#     0.0133,
#     0.0251,
#     0.0098,
#     0.054,
#     0.0163,
#     0.0533,
#     0.0396,
#     0.0468]}]]

# %% [markdown]
# ## Execution time comparison

# %% [markdown]
# This will show a function for each execution running. Each execution running is formed by the different maxfevs for which it was run.

# %%
times = []

for itr,result in enumerate(results):
    times.append([])
    for maxfev in maxfevs:
        times[itr].append(result['maxfev '+maxfev]['time'])

# write the functions
for itr,time in enumerate(times):
    plt.plot(maxfevs, time, label=file_names[itr])

# peronalize labels
plt.xlabel('maxfev')
plt.ylabel('time in seconds')
plt.title('Time required for optimizing')
plt.legend()

plt.show()

# %% [markdown]
# GPU time function keep an expected linear evolution. But cpu_statevector starts with an exponential evolution from 100 to 750, and having a great decrease for 1000 maxfev. This kind of courious, it will be interesting discovering if it has deterministic reason.

# %% [markdown]
# ## approximate solutions probabilities comparison

# %% [markdown]
# For each execution running and maxfev, we will show the sum of ocurrance probabilities for the 10 most approximate solutions found.

# %%
probabilities = []
for itr,problem in enumerate(lowest_cost_bitstrings):
    probabilities.append([])
    for lcb in problem:
        probabilities[itr].append(sum(lcb['probabilities']))

for itr,probs in enumerate(probabilities):
    plt.plot(maxfevs, probs, label=file_names[itr])

# peronalize labels
plt.xlabel('maxfev')
plt.ylabel('probability')
plt.title('Probability of measuring the 10 most approximate solutions')
plt.legend()

plt.show()

# %% [markdown]
# In some way, a better probability performance trough giving more maxfevs can be seen. Of course, because QC is probabilitic, some stochastic behaviour is seen. But, in general terms, the occurance probability is logical.

# %% [markdown]
# ## Are all approximate solutions found feasible?

# %% [markdown]
# The next cell analyze for each (execution running,maxfev) if all the solutions found are feasible.

# %%
def is_feasible(bitstring):
    num_vacnJobs = 6
    
    for itr in range(0,len(bitstring),num_vacnJobs):
        sum = 0
        for i in range(itr,itr+num_vacnJobs):
            #print(bitstring[i])
            sum += int(bitstring[i])
        #print('res=',sum)
        if sum > 1:
            #print('sale')
            return False
    return True

for itr,problem in enumerate(lowest_cost_bitstrings):
    for itr2,lcb in enumerate(problem):
        feasible = True
        total_feasible_solutions = 0
        for solution_bitstring in lcb['solutions_bitstrings']:
            feasible = is_feasible(solution_bitstring)
            print('is_feasible(',file_names[itr],',',maxfevs[itr2],',',solution_bitstring,'):',feasible)
            if feasible:
                total_feasible_solutions += 1
        print('TOTAL FEASIBLE SOLUTIONS: ',total_feasible_solutions,'/10\n')
# Out:
# is_feasible( cpu_statevector , 100 , 000001010000000000 ): True
# is_feasible( cpu_statevector , 100 , 000001000000010000 ): True
# is_feasible( cpu_statevector , 100 , 000001010000100000 ): True
# is_feasible( cpu_statevector , 100 , 000100010000001000 ): True
# is_feasible( cpu_statevector , 100 , 000001100000010000 ): True
# is_feasible( cpu_statevector , 100 , 000000010000001000 ): True
# is_feasible( cpu_statevector , 100 , 000100001000010000 ): True
# is_feasible( cpu_statevector , 100 , 000010000000001000 ): True
# is_feasible( cpu_statevector , 100 , 000000001000010000 ): True
# is_feasible( cpu_statevector , 100 , 000010001000000000 ): True
# TOTAL FEASIBLE SOLUTIONS:  10 /10
#
# is_feasible( cpu_statevector , 250 , 000001010000000000 ): True
# is_feasible( cpu_statevector , 250 , 000001000000010000 ): True
# is_feasible( cpu_statevector , 250 , 000001010000100000 ): True
# is_feasible( cpu_statevector , 250 , 000100010000001000 ): True
# is_feasible( cpu_statevector , 250 , 000001100000010000 ): True
# is_feasible( cpu_statevector , 250 , 000000010000001000 ): True
# is_feasible( cpu_statevector , 250 , 000100001000010000 ): True
# is_feasible( cpu_statevector , 250 , 000010000000001000 ): True
# is_feasible( cpu_statevector , 250 , 000000001000010000 ): True
# is_feasible( cpu_statevector , 250 , 000010001000000000 ): True
# TOTAL FEASIBLE SOLUTIONS:  10 /10
#
# is_feasible( cpu_statevector , 500 , 000001010000000000 ): True
# is_feasible( cpu_statevector , 500 , 000001000000010000 ): True
# is_feasible( cpu_statevector , 500 , 000001010000100000 ): True
# is_feasible( cpu_statevector , 500 , 000100010000001000 ): True
# is_feasible( cpu_statevector , 500 , 000001100000010000 ): True
# is_feasible( cpu_statevector , 500 , 000000010000001000 ): True
# is_feasible( cpu_statevector , 500 , 000100001000010000 ): True
# is_feasible( cpu_statevector , 500 , 000010000000001000 ): True
# is_feasible( cpu_statevector , 500 , 000000001000010000 ): True
# is_feasible( cpu_statevector , 500 , 000010001000000000 ): True
# TOTAL FEASIBLE SOLUTIONS:  10 /10
#
# is_feasible( cpu_statevector , 750 , 000001010000000000 ): True
# is_feasible( cpu_statevector , 750 , 000001000000010000 ): True
# is_feasible( cpu_statevector , 750 , 000001010000100000 ): True
# is_feasible( cpu_statevector , 750 , 000100010000001000 ): True
# is_feasible( cpu_statevector , 750 , 000001100000010000 ): True
# is_feasible( cpu_statevector , 750 , 000000010000001000 ): True
# is_feasible( cpu_statevector , 750 , 000100001000010000 ): True
# is_feasible( cpu_statevector , 750 , 000010000000001000 ): True
# is_feasible( cpu_statevector , 750 , 000000001000010000 ): True
# is_feasible( cpu_statevector , 750 , 000010001000000000 ): True
# TOTAL FEASIBLE SOLUTIONS:  10 /10
#
# is_feasible( cpu_statevector , 1000 , 000001010000000000 ): True
# is_feasible( cpu_statevector , 1000 , 000001000000010000 ): True
# is_feasible( cpu_statevector , 1000 , 000001010000100000 ): True
# is_feasible( cpu_statevector , 1000 , 000100010000001000 ): True
# is_feasible( cpu_statevector , 1000 , 000001100000010000 ): True
# is_feasible( cpu_statevector , 1000 , 000000010000001000 ): True
# is_feasible( cpu_statevector , 1000 , 000100001000010000 ): True
# is_feasible( cpu_statevector , 1000 , 000010000000001000 ): True
# is_feasible( cpu_statevector , 1000 , 000000001000010000 ): True
# is_feasible( cpu_statevector , 1000 , 000010001000000000 ): True
# TOTAL FEASIBLE SOLUTIONS:  10 /10
#
# is_feasible( gpu_statevector , 100 , 000001010000000000 ): True
# is_feasible( gpu_statevector , 100 , 000001000000010000 ): True
# is_feasible( gpu_statevector , 100 , 000001010000100000 ): True
# is_feasible( gpu_statevector , 100 , 000100010000001000 ): True
# is_feasible( gpu_statevector , 100 , 000001100000010000 ): True
# is_feasible( gpu_statevector , 100 , 000000010000001000 ): True
# is_feasible( gpu_statevector , 100 , 000100001000010000 ): True
# is_feasible( gpu_statevector , 100 , 000010000000001000 ): True
# is_feasible( gpu_statevector , 100 , 000000001000010000 ): True
# is_feasible( gpu_statevector , 100 , 000010001000000000 ): True
# TOTAL FEASIBLE SOLUTIONS:  10 /10
#
# is_feasible( gpu_statevector , 250 , 000001010000000000 ): True
# is_feasible( gpu_statevector , 250 , 000001000000010000 ): True
# is_feasible( gpu_statevector , 250 , 000001010000100000 ): True
# is_feasible( gpu_statevector , 250 , 000100010000001000 ): True
# is_feasible( gpu_statevector , 250 , 000001100000010000 ): True
# is_feasible( gpu_statevector , 250 , 000000010000001000 ): True
# is_feasible( gpu_statevector , 250 , 000100001000010000 ): True
# is_feasible( gpu_statevector , 250 , 000010000000001000 ): True
# is_feasible( gpu_statevector , 250 , 000000001000010000 ): True
# is_feasible( gpu_statevector , 250 , 000010001000000000 ): True
# TOTAL FEASIBLE SOLUTIONS:  10 /10
#
# is_feasible( gpu_statevector , 500 , 000001010000000000 ): True
# is_feasible( gpu_statevector , 500 , 000001000000010000 ): True
# is_feasible( gpu_statevector , 500 , 000001010000100000 ): True
# is_feasible( gpu_statevector , 500 , 000100010000001000 ): True
# is_feasible( gpu_statevector , 500 , 000001100000010000 ): True
# is_feasible( gpu_statevector , 500 , 000000010000001000 ): True
# is_feasible( gpu_statevector , 500 , 000100001000010000 ): True
# is_feasible( gpu_statevector , 500 , 000010000000001000 ): True
# is_feasible( gpu_statevector , 500 , 000000001000010000 ): True
# is_feasible( gpu_statevector , 500 , 000010001000000000 ): True
# TOTAL FEASIBLE SOLUTIONS:  10 /10
#
# is_feasible( gpu_statevector , 750 , 000001010000000000 ): True
# is_feasible( gpu_statevector , 750 , 000001000000010000 ): True
# is_feasible( gpu_statevector , 750 , 000001010000100000 ): True
# is_feasible( gpu_statevector , 750 , 000100010000001000 ): True
# is_feasible( gpu_statevector , 750 , 000001100000010000 ): True
# is_feasible( gpu_statevector , 750 , 000000010000001000 ): True
# is_feasible( gpu_statevector , 750 , 000100001000010000 ): True
# is_feasible( gpu_statevector , 750 , 000010000000001000 ): True
# is_feasible( gpu_statevector , 750 , 000000001000010000 ): True
# is_feasible( gpu_statevector , 750 , 000010001000000000 ): True
# TOTAL FEASIBLE SOLUTIONS:  10 /10
#
# is_feasible( gpu_statevector , 1000 , 000001010000000000 ): True
# is_feasible( gpu_statevector , 1000 , 000001000000010000 ): True
# is_feasible( gpu_statevector , 1000 , 000001010000100000 ): True
# is_feasible( gpu_statevector , 1000 , 000100010000001000 ): True
# is_feasible( gpu_statevector , 1000 , 000001100000010000 ): True
# is_feasible( gpu_statevector , 1000 , 000000010000001000 ): True
# is_feasible( gpu_statevector , 1000 , 000100001000010000 ): True
# is_feasible( gpu_statevector , 1000 , 000010000000001000 ): True
# is_feasible( gpu_statevector , 1000 , 000000001000010000 ): True
# is_feasible( gpu_statevector , 1000 , 000010001000000000 ): True
# TOTAL FEASIBLE SOLUTIONS:  10 /10

# %% [markdown]
# All the most probable solutions are feasible!

# %% [markdown]
# ## Cost histories comparison

# %%
for maxfev in maxfevs:
    fig, ax = plt.subplots()
    results[0]['maxfev '+maxfev]['result'].plot_cost(label='cpu_statevector',ax=ax)
    results[1]['maxfev '+maxfev]['result'].plot_cost(label='gpu_statevector',color='orange',ax=ax)
    ax.set_title('Cost history - maxfev '+maxfev)

# %% [markdown]
# For maxfev 100 and 250 cost histories, prety similar optimization happened. Maxfev 500 and 750 optimization is preety similar, but when going to end of the cost histories, GPU start having a worse beaviuour (nothing to exagerated).  The maxfev 1000 optimization also has similar cost histories for cpu and gpu running, but in this case, GPU is the one outperforming a little bit.
#
# The only optimization where the optimizer stop before the manual stopping was for CPU and GPU maxfev 1000 optimization. The stop in between 800 and 900 fevs.

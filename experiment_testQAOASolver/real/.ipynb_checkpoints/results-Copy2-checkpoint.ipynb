# %% [markdown]
# # Results

# %%
SAVE_IN_ENGLISH = True

# %% [markdown]
# ### Uploading the experiment files

# %%
import os
import json
import sys

import pandas as pd
import numpy as np

from openqaoa.algorithms import QAOAResult
import matplotlib.pyplot as plt
from matplotlib import rcParams
#Parametros para graficas
#plt.style.use('dark_background')
rcParams.update( {'xtick.labelsize': 15, 'ytick.labelsize': 15, 'font.size': 18} )

from scipy.stats import norm,stats
from scipy.ndimage import zoom

sys.path.append(os.path.abspath(os.path.join('../..', 'functions')))
from JRPClassic import JRPClassic
from utils import *

# %%
files ={}
directory = './results'

for file in os.listdir(directory):
    if file.endswith('.json'):
        full_path = os.path.join(directory, file)
        with open(full_path, 'r', encoding='utf-8') as f:
            filename = os.path.splitext(file)[0]
            files[filename] = json.load(f)

# %%
keys = list(files.keys())

# %% [markdown]
# ### Presenting the files

# %% [markdown]
# There is a total of 21 files, where each has a corresponding JRP initialization configuration and circuit configuration. Each file has a sample of 5 instances, resulting in a total sample of $5 \cdot 21 = 105$ JRP instances.

# %% [markdown]
# Apart from its file name, a configuration is defined as a tuple $(a,v,p)$, where $a$ is the number of agents, $v$ is the number of vacant jobs and $p$ is the corresponding hyperparameter of a QAOA ansatz.

# %%
dfs = []
configurations_names = []
for filename, data in files.items():
    # Extract specific data based on keys_to_extract
    jrp_configuration = data['jrp_configuration']
    circuit_configuration = data['circuit_configuration']

    num_agents = jrp_configuration['num_agents']
    num_vacnJobs = jrp_configuration['num_vacnJobs']
    p = circuit_configuration['p']
    configuration_name = f'({num_agents},{num_vacnJobs},{p})'
    configurations_names.append(configuration_name)
    
    row = {'file_name':filename,'configuration':configuration_name,**jrp_configuration,**circuit_configuration}
    
    columns = ['file_name','configuration']+list(jrp_configuration.keys()) + list(circuit_configuration.keys())
    
    # Convert the extracted data into a DataFrame
    pd.set_option('display.width', 1000)  # Set a large width to prevent wrapping
    df = pd.DataFrame([[row.get(col) for col in columns]],columns=columns)
    dfs.append(df)

df = pd.concat(dfs, ignore_index=True)
df.index = df.index + 1

df
#df.to_csv('results/csvs/files_and_configurations.csv')
# Out:
#                          file_name configuration  num_agents  num_vacnJobs  penalty1  penalty2  control_restrictions  p param_type init_type mixer_hamiltonian
# 1   conf_jrpInitConf0_circuitConf0       (5,3,3)           5             3       2.5         3                 False  3   standard      ramp                 x
# 2   conf_jrpInitConf0_circuitConf1       (5,3,4)           5             3       2.5         3                 False  4   standard      ramp                 x
# 3   conf_jrpInitConf0_circuitConf2       (5,3,5)           5             3       2.5         3                 False  5   standard      ramp                 x
# 4   conf_jrpInitConf1_circuitConf0       (3,5,3)           3             5       2.5         3                 False  3   standard      ramp                 x
# 5   conf_jrpInitConf1_circuitConf1       (3,5,4)           3             5       2.5         3                 False  4   standard      ramp                 x
# 6   conf_jrpInitConf1_circuitConf2       (3,5,5)           3             5       2.5         3                 False  5   standard      ramp                 x
# 7   conf_jrpInitConf2_circuitConf0       (6,3,3)           6             3       2.5         3                 False  3   standard      ramp                 x
# 8   conf_jrpInitConf2_circuitConf1       (6,3,4)           6             3       2.5         3                 False  4   standard      ramp                 x
# 9   conf_jrpInitConf2_circuitConf2       (6,3,5)           6             3       2.5         3                 False  5   standard      ramp                 x
# 10  conf_jrpInitConf3_circuitConf0       (3,6,3)           3             6       2.5         3                 False  3   standard      ramp                 x
# 11  conf_jrpInitConf3_circuitConf1       (3,6,4)           3             6       2.5         3                 False  4   standard      ramp                 x
# 12  conf_jrpInitConf3_circuitConf2       (3,6,5)           3             6       2.5         3                 False  5   standard      ramp                 x
# 13  conf_jrpInitConf4_circuitConf0       (5,4,3)           5             4       2.5         3                 False  3   standard      ramp                 x
# 14  conf_jrpInitConf4_circuitConf1       (5,4,4)           5             4       2.5         3                 False  4   standard      ramp                 x
# 15  conf_jrpInitConf4_circuitConf2       (5,4,5)           5             4       2.5         3                 False  5   standard      ramp                 x
# 16  conf_jrpInitConf5_circuitConf0       (4,5,3)           4             5       2.5         3                 False  3   standard      ramp                 x
# 17  conf_jrpInitConf5_circuitConf1       (4,5,4)           4             5       2.5         3                 False  4   standard      ramp                 x
# 18  conf_jrpInitConf5_circuitConf2       (4,5,5)           4             5       2.5         3                 False  5   standard      ramp                 x
# 19  conf_jrpInitConf6_circuitConf0       (4,4,3)           4             4       2.5         3                 False  3   standard      ramp                 x
# 20  conf_jrpInitConf6_circuitConf1       (4,4,4)           4             4       2.5         3                 False  4   standard      ramp                 x
# 21  conf_jrpInitConf6_circuitConf2       (4,4,5)           4             4       2.5         3                 False  5   standard      ramp                 x

# %% [markdown]
# ### Approximation ratio

# %% [markdown]
# We will read the approximation ratio for each (file,sample). The structure saved is a list where an element (i,j) corresponds to file i and sample j.

# %%
approximation_ratios = []

instances_indexes = range(5)
for file_index,(filename,data) in enumerate(files.items()):
    approximation_ratios.append([])
    
    for instance_index in instances_indexes:
        approximation_ratios[file_index].append(data[str(instance_index)]['approximation_ratio'])

# %% [markdown]
# Some hyperparameters for visualization.

# %%
np.random.seed(0)
data = np.array(approximation_ratios)

nums_files = data.shape[0]
first_files = nums_files // 2
last_files =  nums_files - nums_files // 2
num_samples_per_file = data.shape[1]

# %% [markdown]
# We define a set of colors for some of the following plots.

# %%
colors_reds = plt.cm.Reds(np.linspace(0.3, 0.9, num_samples_per_file))
colors_blues = plt.cm.Blues(np.linspace(0.3, 0.9, num_samples_per_file))
colors_greens = plt.cm.Greens(np.linspace(0.3, 0.9, num_samples_per_file))
colors_purples = plt.cm.Purples(np.linspace(0.3, 0.9, num_samples_per_file))
colors_oranges = plt.cm.Oranges(np.linspace(0.3, 0.9, num_samples_per_file))
colors_greys = plt.cm.Greys(np.linspace(0.3, 0.9, num_samples_per_file))
colors_pinks = plt.cm.BuGn(np.linspace(0.3, 0.9, num_samples_per_file))
colors_cool = plt.cm.OrRd(np.linspace(0.3, 0.9, num_samples_per_file))
colors_copper = plt.cm.PuBu(np.linspace(0.3, 0.9, num_samples_per_file))
colors_viridis = plt.cm.viridis(np.linspace(0.3, 0.9, num_samples_per_file))
colors_magma = plt.cm.magma(np.linspace(0.3, 0.9, num_samples_per_file))
colors = np.array([colors_reds,colors_blues,colors_greens,colors_purples,colors_oranges,colors_greys,colors_pinks,colors_cool,colors_copper,colors_viridis,colors_magma])

# %% [markdown]
# The following plot groups the instances sampled per configuration, and show for each one, its corresponding approximation ratio. As a first result, it can be seen that most of the instances has succesful approximation ratio, since no one of them has a ratio lower than $0.6$, and most of them seems to variate in the range between $0.7$ to $1$.

# %%
# Create a bar plot
fig, ax = plt.subplots(figsize=(14, 4))
markers = ['o', '^', 's', 'D', 'p']  
linestyles = ['-', '--', '-.', ':']  
bar_width = 0.5
category_width = 3  

if SAVE_IN_ENGLISH:
    xlabel = 'Configuration (n_agents, n_vacantJobs, p)'
    ylabel = 'Approximation ratio'
    title = 'Approximation ratio for the JRP instances of all configurations'
    save_dir = 'results/aproximation_ratio/aproxratio_per_instance'
    legend_elements = [plt.Line2D([0], [0], marker=markers[i], color='w', label=f'Instance {i+1}', 
                              markerfacecolor='k', markersize=10) for i in range(num_samples_per_file)]
else:
    xlabel = 'Configuración (n_trabajadores, n_puestosVacantes, p)'
    ylabel = 'Razón de Aproximación'
    title = 'Razón de Aproximación para las instancias JRP de todas las configuraciones'
    save_dir = '../../spanish_imgs/notebooks/results/aproximation_ratio/aproxratio_per_instance'
    legend_elements = [plt.Line2D([0], [0], marker=markers[i], color='w', label=f'Instancia {i+1}', 
                              markerfacecolor='k', markersize=10) for i in range(num_samples_per_file)]

# Plot bars for each group
for i in range(num_samples_per_file):
    for j in range(0,first_files):
        ax.plot(np.arange(first_files)[j] * category_width  + i * bar_width / num_samples_per_file,  # Desplazamiento de los puntos
            data[j, i],
            'o', 
            color=colors[j][i],
            marker=markers[i],
            markersize=10,
            label=f'Group {i+1}',
            markeredgewidth=2,  
            markeredgecolor='black'  )

# Add labels, title, and legend
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)
ax.legend(handles=legend_elements,  loc='upper left', bbox_to_anchor=(1, 1),handletextpad=0.01)
plt.xticks(np.arange(first_files) * category_width  + bar_width / 2, labels=[f'{configurations_names[i]}' for i in range(first_files)])
plt.tight_layout()
plt.savefig(save_dir+"/1.png", bbox_inches='tight')  # Guardar la figura en un archivo
plt.show()

fig, ax = plt.subplots(figsize=(14, 4))
for i in range(num_samples_per_file):
    for j in range(last_files):
        ax.plot(np.arange(last_files)[j] * category_width  + i * bar_width / num_samples_per_file, 
            data[first_files+j, i],
            'o', 
            color=colors[j][i],
            marker=markers[i],
            markersize=10,
            label=f'Group {i+1}',
            markeredgewidth=2,  
            markeredgecolor='black',)

# Add labels, title, and legend
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)
ax.legend(handles=legend_elements,  loc='upper left', bbox_to_anchor=(1, 1),handletextpad=0.01)


plt.xticks(np.arange(last_files) * category_width  + bar_width / 2, [f'{configurations_names[i]}' for i in  range(last_files-1,nums_files)])
#ax.set_yticks(np.arange(0, 1.1, 0.1) )
plt.tight_layout()
plt.savefig(save_dir+"/2.png", bbox_inches='tight')  # Guardar la figura en un archivo
plt.show()
# PROBRAS AGREGAR BORDES SOBRE CADA FIGURITA (CON UN MARKERSIZE) PARA QUE SE NOTEN MEJOR LAS FORMITAS
# Out:
# C:\Users\Adriano\AppData\Local\Temp\ipykernel_4356\723874723.py:26: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(np.arange(first_files)[j] * category_width  + i * bar_width / num_samples_per_file,  # Desplazamiento de los puntos
# C:\Users\Adriano\AppData\Local\Temp\ipykernel_4356\723874723.py:48: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(np.arange(last_files)[j] * category_width  + i * bar_width / num_samples_per_file,

# %%
column_names = ['Instance 1', 'Instance 2', 'Instance 3', 'Instance 4', 'Instance 5']
df = pd.DataFrame(data,columns=column_names)
df.insert(0,'configuration',configurations_names)
df.to_csv('results/csvs/approximation_ratio/approximation_ratio_per_configuration.csv')

# %% [markdown]
# The following plot show statistics of approximation ratio for different instances groups. These groups are form depending the JRP configuration used. That means, the amount of agent and vancancy jobs assigned to the problem. There is no important discussion here.

# %%
subdatas = [data.flatten()]
for index in range(0,len(data),3):
    subdatas.append(np.concatenate((data[index],data[index+1],data[index+2])))

means = [np.mean(subdata, axis=0) for subdata in subdatas]

plt.figure(figsize=(10, 4))
categories =  ['all\nsamples','(5,3,p)','(3,5,p)',
               '(6,3,p)','(3,6,p)',
               '(5,4,p)','(4,5,p)',
               '(4,4,p)']

plt.boxplot(subdatas,labels=categories,usermedians=means)

plt.xlabel('JRP configuration (num_agents, num_vacantJobs)')
plt.ylabel('Aproximation ratio')

plt.savefig("results/aproximation_ratio/aproxratio_per_jrpconfiguration.png", bbox_inches='tight')  # Guardar la figura en un archivo
plt.show()

# %% [markdown]
# The following plot show statistics of approximation ratio for different instances group. These groups are form depending the circuit width. It is important to remember that the circuit width is going to be the product between the amount of agent and the amount of vacancy jobs. Usually, in QAOA, a bigger circuit with will be related to a bigger circuit depth. Because using more qubits means using more variables, it will also been translated to a larger cost hamiltonian.
#
# For larger problem (and by that, circuit depth and width) eithera bigger p value and bigger amount of optimization steps would be needed. This makes sense with the results show below. It can be seen that, the bigger the circuit width, the smaller is the meadian approximation ratio. There is a much noticed decrease in performance when jumping from a width of 18 to 20. The median decrease is even larger, and also, the $q1-q3$ interval shift to lower values.

# %%
subdatas = [data.flatten()]
for index in range(0,len(data)-6,6):
    subdatas.append(np.concatenate((data[index],data[index+1],data[index+2],data[index+3],data[index+4],data[index+5])))
#[keys[18],data[19],data[20]]
means = [np.mean(subdata, axis=0) for subdata in subdatas]

plt.figure(figsize=(6, 4))

if SAVE_IN_ENGLISH:
    plt.xlabel('Problem size')
    plt.ylabel('Aproximation ratio')
    categories =  ['all samples',15,18,20]
    save_dir = "results/aproximation_ratio/aproxratio_per_problemsize.png"
else:
    plt.xlabel('Tamaño del problema')
    plt.ylabel('Razón de Aproximación')
    categories =  ['todas las\nmuestras',15,18,20]
    save_dir = "../../spanish_imgs/notebooks/results/aproximation_ratio/aproxratio_per_problemsize.png"

boxplot_stats= plt.boxplot(subdatas,labels=categories,usermedians=means)
plt.savefig(save_dir, bbox_inches='tight')  # Guardar la figura en un archivo
plt.show()

# %%
num_categories =len(categories)
statistics = np.zeros((num_categories, 5))  
for i in range(num_categories):
    # Boxplot stats
    box = boxplot_stats['boxes'][i].get_ydata()
    whiskers = boxplot_stats['whiskers'][2*i:2*i+2]
    means = boxplot_stats['medians'][i].get_ydata()
    caps = boxplot_stats['caps'][2*i:2*i+2]
    
    # Agregar estadísticas
    statistics[i, 0] = round(means[1],3)  # Mediana
    statistics[i, 1] = round(box[0],3)    # 25th percentile
    statistics[i, 2] =round(box[2],3)      # 75th percentile
    statistics[i, 3] = round(whiskers[0].get_ydata()[1],3)  # Bigote inferior
    statistics[i, 4] = round(whiskers[1].get_ydata()[1],3) # Bigote superior

column_names = ['mean','q1','q3','min.','max.']
df = pd.DataFrame(statistics[1:][:],columns=column_names)
df.insert(0,'problem size',[15,18,20])
df.to_csv('results/csvs/approximation_ratio/approximation_ratio_per_problem_size.csv')

# %% [markdown]
# The following plot show statistics of approximation ratio for different instances group. These groups are form depending p value chosen. It is important to remember that, theoretically, when $p \rightarrow \infty$, then the approximation ratio also tends to $1$.
#
# As expected, it could be seen that incrementing the p value help to increase the approximation ratio statistics. The bigger jump is done from $p=3$ to $p=4$, specially when comparing the medians. Although the jump from $p=4$ to $p=5$ has near no change in the median, there is shift to bigger values of the $q1-q3$ interval, and an increase of the min value found.

# %%
subdatas = [data.flatten()]
for index in range(0,3):
    aux = np.array([])
    for index2 in range(0,21,3):
        aux=np.concatenate((aux,data[index+index2]))
    subdatas.append(aux)

means = [np.mean(subdata, axis=0) for subdata in subdatas]

plt.figure(figsize=(6, 4))

if SAVE_IN_ENGLISH:
    categories =  ['all samples',3,4,5]
    plt.xlabel('p')
    plt.ylabel('Aproximation ratio')
    save_dir = "results/aproximation_ratio/aproxratio_per_p.png"
else:
    categories =  ['todas las\nmuestras',3,4,5]
    plt.xlabel('p')
    plt.ylabel('Razón de Aproximación')
    save_dir = "../../spanish_imgs/notebooks/results/aproximation_ratio/aproxratio_per_p.png"

boxplot_stats = plt.boxplot(subdatas,labels=categories,usermedians=means)



plt.savefig(save_dir, bbox_inches='tight')  # Guardar la figura en un archivo
plt.show()

# %%
num_categories =len(categories)
statistics = np.zeros((num_categories, 5))  
for i in range(num_categories):
    # Boxplot stats
    box = boxplot_stats['boxes'][i].get_ydata()
    whiskers = boxplot_stats['whiskers'][2*i:2*i+2]
    means = boxplot_stats['medians'][i].get_ydata()
    caps = boxplot_stats['caps'][2*i:2*i+2]
    
    # Agregar estadísticas
    statistics[i, 0] = round(means[1],3)  # Mediana
    statistics[i, 1] = round(box[0],3)    # 25th percentile
    statistics[i, 2] =round(box[2],3)      # 75th percentile
    statistics[i, 3] = round(whiskers[0].get_ydata()[1],3)  # Bigote inferior
    statistics[i, 4] = round(whiskers[1].get_ydata()[1],3) # Bigote superior

column_names = ['mean','q1','q3','min.','max.']
df = pd.DataFrame(statistics[1:][:],columns=column_names)
df.insert(0,'p',[3,4,5])
df.to_csv('results/csvs/approximation_ratio/approximation_ratio_per_p.csv')

# %% [markdown]
# Finally, the following is an histogram of the complete $105$ sample set.

# %%
aux_data = data.flatten() 
n_bars=len(set(aux_data))
# Calculate mean and standard deviation from the dataset
mean = np.mean(aux_data)
std_dev = np.std(aux_data)

# Plot histogram of the dataset
plt.figure(figsize=(10, 6))
plt.hist(aux_data, bins=n_bars, density=False, alpha=0.6, label='Data Histogram')

# Plot the Gaussian curve
if SAVE_IN_ENGLISH:
    plt.xlabel('Approximation ratio')
    plt.ylabel('Frequency')
    save_dir = "results/aproximation_ratio/aproxratio_completeHistogram.png"
else:
    plt.xlabel('Razón de Aproximación')
    plt.ylabel('Frecuencia')
    save_dir = "../../spanish_imgs/notebooks/results/aproximation_ratio/aproxratio_completeHistogram.png"

plt.savefig(save_dir, bbox_inches='tight')  # Guardar la figura en un archivo
plt.show()

# %% [markdown]
# ### Optimizer's function evaluation

# %%
q_results = []
structured_fevs = []

instances_indexes = range(5)
for file_index,(filename,data2) in enumerate(files.items()):
    q_results.append([])
    structured_fevs.append([])
    
    for instance_index in instances_indexes:
        q_result =  QAOAResult.from_dict(data2[str(instance_index)]['result'])
        q_results[file_index].append(
            q_result
        )
        structured_fevs[file_index].append(q_result.evals['number_of_evals'])
structured_fevs = np.array(structured_fevs)

# %%
# Create a bar plot
fig, ax = plt.subplots(figsize=(14, 4))
markers = ['o', '^', 's', 'D', 'p']  
linestyles = ['-', '--', '-.', ':']  
bar_width = 0.5
category_width = 3  

if SAVE_IN_ENGLISH:
    xlabel = 'Configuración (n_trabajadores, n_puestosVacantes, p)'
    ylabel = 'Evaluaciones de función'
    save_dir = 'results/optimizer_functionEvaluations/functioneval_per_instance'
    legend_elements = [plt.Line2D([0], [0], marker=markers[i], color='w', label=f'Instance {i+1}', 
                              markerfacecolor='k', markersize=10) for i in range(num_samples_per_file)]
else:
    xlabel = 'Configuración (n_trabajadores, n_puestosVacantes, p)'
    ylabel = 'Evaluaciones de función'
    save_dir = '../../spanish_imgs/notebooks/results/optimizer_functionEvaluations/functioneval_per_instance'
    legend_elements = [plt.Line2D([0], [0], marker=markers[i], color='w', label=f'Instancia {i+1}', 
                              markerfacecolor='k', markersize=10) for i in range(num_samples_per_file)]

# Plot bars for each group
for i in range(num_samples_per_file):
    for j in range(0,first_files):
        ax.plot(np.arange(first_files)[j] * category_width  + i * bar_width / num_samples_per_file,  # Desplazamiento de los puntos
            structured_fevs[j, i],
            'o', 
            color=colors[j][i],
            marker=markers[i],
            markersize=10,
            label=f'Group {i+1}',
                markeredgewidth=2,  
            markeredgecolor='black')

# Add labels, title, and legend
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)

ax.legend(handles=legend_elements,  loc='upper left', bbox_to_anchor=(1, 1),handletextpad=0.01)
plt.xticks(np.arange(first_files) * category_width  + bar_width / 2, labels=[f'{configurations_names[i]}' for i in range(first_files)])
plt.tight_layout()
plt.savefig(save_dir+"/1.png", bbox_inches='tight')  # Guardar la figura en un archivo
plt.show()

fig, ax = plt.subplots(figsize=(14, 4))
for i in range(num_samples_per_file):
    for j in range(last_files):
        ax.plot(np.arange(last_files)[j] * category_width  + i * bar_width / num_samples_per_file, 
            structured_fevs[first_files+j, i],
            'o', 
            color=colors[j][i],
            marker=markers[i],
            markersize=10,
            label=f'Group {i+1}',
               markeredgewidth=2,  
            markeredgecolor='black')

# Add labels, title, and legend
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)
ax.legend(handles=legend_elements,  loc='upper left', bbox_to_anchor=(1, 1),handletextpad=0.01)


plt.xticks(np.arange(last_files) * category_width  + bar_width / 2, [f'{configurations_names[i]}' for i in  range(last_files-1,nums_files)])
#ax.set_yticks(np.arange(0, 1.1, 0.1) )
plt.tight_layout()
plt.savefig(save_dir+"/2.png", bbox_inches='tight')  # Guardar la figura en un archivo
plt.show()
# Out:
# C:\Users\Adriano\AppData\Local\Temp\ipykernel_4356\968856985.py:24: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(np.arange(first_files)[j] * category_width  + i * bar_width / num_samples_per_file,  # Desplazamiento de los puntos
# C:\Users\Adriano\AppData\Local\Temp\ipykernel_4356\968856985.py:47: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(np.arange(last_files)[j] * category_width  + i * bar_width / num_samples_per_file,

# %%
column_names = ['Instance 1', 'Instance 2', 'Instance 3', 'Instance 4', 'Instance 5']
df = pd.DataFrame(structured_fevs,columns=column_names)
df.insert(0,'configuration',configurations_names)
df.to_csv('results/csvs/function_evaluations/function_evaluations_per_configuration.csv')

# %%
fevs = []
for conf in q_results:
    for res in conf:
        fevs.append(res.evals['number_of_evals'])
n_bars = len(set(fevs))
# Step 1: Plot frequency histogram
count, bins, ignored = plt.hist(fevs, bins=n_bars, density=False, alpha=0.6,label='histogram')

if SAVE_IN_ENGLISH:
    plt.xlabel('Function evaluations')
    plt.ylabel('Frequency')
    save_dir="results/optimizer_functionEvaluations/functioneval_completeHistogram.png"
else:
    plt.xlabel('Evaluaciones de función')
    plt.ylabel('Frecuencia')
    save_dir="../../spanish_imgs/notebooks/results/optimizer_functionEvaluations/functioneval_completeHistogram.png"

# Step 2: Fit a normal distribution to the data
mu, std = norm.fit(fevs)

# Step 3: Plot the Gaussian curve scaled to match the histogram
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)

# Scale the Gaussian curve by the total number of data points and the width of the bins
bin_width = bins[1] - bins[0]
p_scaled = p * len(fevs) * bin_width

#plt.plot(x, p_scaled, 'k', linewidth=2,label='gaussian fit')

textstr = f'Mean = {mu:.2f}\nStd Dev = {std:.2f}'
props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
#plt.text(xmax * 0.7, p_scaled.max() * 0.8, textstr, fontsize=12, bbox=props)


#plt.legend()

#plt.grid(True)
plt.savefig(save_dir, bbox_inches='tight')  # Guardar la figura en un archivo
plt.show()

# %%
subfevs = np.array(fevs[:90])
subfevs = subfevs.reshape((3, 30)).tolist()
subfevs.insert(1,fevs[90:])
subfevs.insert(0,fevs)

means = [np.mean(sbf, axis=0) for sbf in subfevs]

plt.figure(figsize=(6, 4))

if SAVE_IN_ENGLISH:
    plt.xlabel('Problem size')
    plt.ylabel('Function evaluations')
    categories =  ['all samples',15,16,18,20]
    save_dir = "results/optimizer_functionEvaluations/functioneval_per_problemsize.png"
else:
    plt.xlabel('Tamaño del problema')
    plt.ylabel('Evaluaciones de función')
    categories =  ['todas las\nmuestras',15,16,18,20]
    save_dir = "../../spanish_imgs/notebooks/results/optimizer_functionEvaluations/functioneval_per_problemsize.png"

boxplot_stats = plt.boxplot(subfevs,labels=categories,usermedians=means)
plt.savefig(save_dir, bbox_inches='tight')  # Guardar la figura en un archivo
plt.show()

# %%
num_categories =len(categories)
statistics = np.zeros((num_categories, 5))  
for i in range(num_categories):
    # Boxplot stats
    box = boxplot_stats['boxes'][i].get_ydata()
    whiskers = boxplot_stats['whiskers'][2*i:2*i+2]
    means = boxplot_stats['medians'][i].get_ydata()
    caps = boxplot_stats['caps'][2*i:2*i+2]
    
    # Agregar estadísticas
    statistics[i, 0] = round(means[1],3)  # Mediana
    statistics[i, 1] = round(box[0],3)    # 25th percentile
    statistics[i, 2] =round(box[2],3)      # 75th percentile
    statistics[i, 3] = round(whiskers[0].get_ydata()[1],3)  # Bigote inferior
    statistics[i, 4] = round(whiskers[1].get_ydata()[1],3) # Bigote superior


column_names = ['mean','q1','q3','min.','max.']
df = pd.DataFrame(statistics[1:][:],columns=column_names)
df.insert(0,'problem size',[15,16,18,20])
df.to_csv('results/csvs/function_evaluations/function_evaluations_per_problem_size.csv')

# %%
#subdatas = [data.flatten()]
subfevs = [fevs]
for index in range(0,3):
    aux = np.array([])
    for index2 in range(0,21,3):
        aux=np.concatenate((aux,structured_fevs[index+index2]))
    subfevs.append(aux)

means = [np.mean(sbf, axis=0) for sbf in subfevs]

plt.figure(figsize=(6, 4))

if SAVE_IN_ENGLISH:
    plt.xlabel('p')
    plt.ylabel('Function evaluations')
    categories =  ['all samples',3,4,5]
    save_dir = "results/optimizer_functionEvaluations/functioneval_per_p.png"
else:
    plt.xlabel('p')
    plt.ylabel('Evaluaciones de función')
    categories =  ['todas las\nmuestras',3,4,5]
    save_dir = "../../spanish_imgs/notebooks/results/optimizer_functionEvaluations/functioneval_per_p.png"

boxplot_stats = plt.boxplot(subfevs,labels=categories,usermedians=means)
plt.savefig(save_dir, bbox_inches='tight')  # Guardar la figura en un archivo
plt.show()

# %%
num_categories =len(categories)
statistics = np.zeros((num_categories, 5))  
for i in range(num_categories):
    # Boxplot stats
    box = boxplot_stats['boxes'][i].get_ydata()
    whiskers = boxplot_stats['whiskers'][2*i:2*i+2]
    means = boxplot_stats['medians'][i].get_ydata()
    caps = boxplot_stats['caps'][2*i:2*i+2]
    
    # Agregar estadísticas
    statistics[i, 0] = round(means[1],3)  # Mediana
    statistics[i, 1] = round(box[0],3)    # 25th percentile
    statistics[i, 2] =round(box[2],3)      # 75th percentile
    statistics[i, 3] = round(whiskers[0].get_ydata()[1],3)  # Bigote inferior
    statistics[i, 4] = round(whiskers[1].get_ydata()[1],3) # Bigote superior

column_names = ['mean','q1','q3','min.','max.']
df = pd.DataFrame(statistics[1:][:],columns=column_names)
df.insert(0,'problem size',[3,4,5])
df.to_csv('results/csvs/function_evaluations/function_evaluations_per_p.csv')

# %% [markdown]
# ### Ising cost differences

# %%
q_results = []
ising_cost_differences = []

instances_indexes = range(5)
for file_index,(filename,data2) in enumerate(files.items()):
    q_results.append([])
    ising_cost_differences.append([])
    
    for instance_index in instances_indexes:
        #q_result =  QAOAResult.from_dict(data2[str(instance_index)]['result'])
        # q_results[file_index].append(
        #      q_result
        # )
        ising_cost_differences[file_index].append(data2[str(instance_index)]['ising_cost_difference'])
ising_cost_differences = np.array(ising_cost_differences)

# %%
# Create a bar plot
fig, ax = plt.subplots(figsize=(14, 4))
markers = ['o', '^', 's', 'D', 'p']  
linestyles = ['-', '--', '-.', ':']  
bar_width = 0.5
category_width = 3  

if SAVE_IN_ENGLISH:
    xlabel = 'Configuration (n_agents, n_vacantJobs, p)'
    ylabel = 'Ising cost difference'
    title = 'Ising cost difference for the JRP instances of all configurations'
    legend_elements = [plt.Line2D([0], [0], marker=markers[i], color='w', label=f'Instance {i+1}', 
                              markerfacecolor='k', markersize=10) for i in range(num_samples_per_file)]
    save_dir = "results/ising_costs/isingcosts_per_instance"
else:
    xlabel = 'Configuración (n_trabajadores, n_puestosVacantes, p)'
    ylabel = 'Diferencia de costo de\nla función Ising'
    title = 'Diferencia de costo de función Ising para las instacias JRP de todas las configuraciones'
    legend_elements = [plt.Line2D([0], [0], marker=markers[i], color='w', label=f'Instancia {i+1}', 
                              markerfacecolor='k', markersize=10) for i in range(num_samples_per_file)]
    save_dir = "../../spanish_imgs/notebooks/results/ising_costs/isingcosts_per_instance"

# Plot bars for each group
for i in range(num_samples_per_file):
    for j in range(0,first_files):
        ax.plot(np.arange(first_files)[j] * category_width  + i * bar_width / num_samples_per_file,  # Desplazamiento de los puntos
            ising_cost_differences[j, i],
            'o', 
            color=colors[j][i],
            marker=markers[i],
            markersize=10,
            label=f'Group {i+1}',
               markeredgewidth=2,  
            markeredgecolor='black')

# Add labels, title, and legend
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)
ax.legend(handles=legend_elements,  loc='upper left', bbox_to_anchor=(1, 1),handletextpad=0.01)
plt.xticks(np.arange(first_files) * category_width  + bar_width / 2, labels=[f'{configurations_names[i]}' for i in range(first_files)])
plt.tight_layout()
plt.savefig(save_dir+"/1.png", bbox_inches='tight')  # Guardar la figura en un archivo
plt.show()

fig, ax = plt.subplots(figsize=(14, 4))
for i in range(num_samples_per_file):
    for j in range(last_files):
        ax.plot(np.arange(last_files)[j] * category_width  + i * bar_width / num_samples_per_file, 
            ising_cost_differences[first_files+j, i],
            'o', 
            color=colors[j][i],
            marker=markers[i],
            markersize=10,
            label=f'Group {i+1}',
               markeredgewidth=2,  
            markeredgecolor='black')

# Add labels, title, and legend
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)
ax.legend(handles=legend_elements,  loc='upper left', bbox_to_anchor=(1, 1),handletextpad=0.01)


plt.xticks(np.arange(last_files) * category_width  + bar_width / 2, [f'{configurations_names[i]}' for i in  range(last_files-1,nums_files)])
#ax.set_yticks(np.arange(0, 1.1, 0.1) )
plt.tight_layout()
plt.savefig(save_dir+"/2.png", bbox_inches='tight')  # Guardar la figura en un archivo
plt.show()
# Out:
# C:\Users\Adriano\AppData\Local\Temp\ipykernel_4356\643276711.py:26: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(np.arange(first_files)[j] * category_width  + i * bar_width / num_samples_per_file,  # Desplazamiento de los puntos
# C:\Users\Adriano\AppData\Local\Temp\ipykernel_4356\643276711.py:48: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(np.arange(last_files)[j] * category_width  + i * bar_width / num_samples_per_file,

# %%
column_names = ['Instance 1', 'Instance 2', 'Instance 3', 'Instance 4', 'Instance 5']
df = pd.DataFrame(ising_cost_differences,columns=column_names)
df.insert(0,'configuration',configurations_names)
df.to_csv('results/csvs/ising_cost_differences/ising_cost_differences_per_configuration.csv')

# %%
aux = ising_cost_differences.flatten()
diffs = np.array(aux[:90])
diffs = diffs.reshape((3, 30)).tolist()
diffs.insert(1,aux[90:])
diffs.insert(0,aux)

means = [np.mean(sbf, axis=0) for sbf in diffs]

plt.figure(figsize=(6, 4))

if SAVE_IN_ENGLISH:
    plt.xlabel('Problem size')
    plt.ylabel('Ising cost difference')
    categories =  ['all samples',15,16,18,20]
    save_dir = "results/ising_costs/isingcosts_per_problemsize.png"
else:
    plt.xlabel('Tamaño del problema')
    plt.ylabel('Diferencia de costo\nde la función Ising')
    categories =  ['todas las\nmuestras',15,16,18,20]
    save_dir = "../../spanish_imgs/notebooks/results/ising_costs/isingcosts_per_problemsize.png" 

boxplot_stats=plt.boxplot(diffs,labels=categories,usermedians=means)
plt.savefig(save_dir, bbox_inches='tight')  # Guardar la figura en un archivo
plt.show()

# %%
num_categories =len(categories)
statistics = np.zeros((num_categories, 5))  
for i in range(num_categories):
    # Boxplot stats
    box = boxplot_stats['boxes'][i].get_ydata()
    whiskers = boxplot_stats['whiskers'][2*i:2*i+2]
    means = boxplot_stats['medians'][i].get_ydata()
    caps = boxplot_stats['caps'][2*i:2*i+2]
    
    # Agregar estadísticas
    statistics[i, 0] = round(means[1],3)  # Mediana
    statistics[i, 1] = round(box[0],3)    # 25th percentile
    statistics[i, 2] =round(box[2],3)      # 75th percentile
    statistics[i, 3] = round(whiskers[0].get_ydata()[1],3)  # Bigote inferior
    statistics[i, 4] = round(whiskers[1].get_ydata()[1],3) # Bigote superior


column_names = ['mean','q1','q3','min.','max.']
df = pd.DataFrame(statistics[1:][:],columns=column_names)
df.insert(0,'problem size',[15,16,18,20])
df.to_csv('results/csvs/ising_cost_differences/ising_cost_differences_per_problem_size.csv')

# %%
#subdatas = [data.flatten()]
diffs = [aux]
for index in range(0,3):
    aux2 = np.array([])
    for index2 in range(0,21,3):
        aux2=np.concatenate((aux2,ising_cost_differences[index+index2]))
    diffs.append(aux2)
means = [np.mean(sbf, axis=0) for sbf in diffs]

plt.figure(figsize=(6, 4))

if SAVE_IN_ENGLISH:
    plt.xlabel('p')
    plt.ylabel('Ising cost difference')
    categories =  ['all samples',3,4,5]
    save_dir = "results/ising_costs/isingcosts_per_p.png"
else:
    plt.xlabel('p')
    plt.ylabel('Diferencia de costo de\nla función Ising')
    categories =  ['todas las\nmuestras',3,4,5]
    save_dir = "../../spanish_imgs/notebooks/results/ising_costs/isingcosts_per_p.png"

boxplot_stats=plt.boxplot(diffs,labels=categories,usermedians=means)
plt.savefig(save_dir, bbox_inches='tight')  # Guardar la figura en un archivo
plt.show()

# %%
num_categories =len(categories)
statistics = np.zeros((num_categories, 5))  
for i in range(num_categories):
    # Boxplot stats
    box = boxplot_stats['boxes'][i].get_ydata()
    whiskers = boxplot_stats['whiskers'][2*i:2*i+2]
    means = boxplot_stats['medians'][i].get_ydata()
    caps = boxplot_stats['caps'][2*i:2*i+2]
    
    # Agregar estadísticas
    statistics[i, 0] = round(means[1],3)  # Mediana
    statistics[i, 1] = round(box[0],3)    # 25th percentile
    statistics[i, 2] =round(box[2],3)      # 75th percentile
    statistics[i, 3] = round(whiskers[0].get_ydata()[1],3)  # Bigote inferior
    statistics[i, 4] = round(whiskers[1].get_ydata()[1],3) # Bigote superior

column_names = ['mean','q1','q3','min.','max.']
df = pd.DataFrame(statistics[1:][:],columns=column_names)
df.insert(0,'problem size',[3,4,5])
df.to_csv('results/csvs/ising_cost_differences/ising_cost_differences_per_per_p.csv')
df
# Out:
#    problem size    mean      q1      q3    min.    max.
# 0             3 -23.641 -31.176 -15.368 -39.736 -10.703
# 1             4 -18.222 -23.756 -13.130 -26.877  -7.177
# 2             5 -18.672 -24.606 -12.242 -28.271  -9.603

# %% [markdown]
# ### Standard gain differences

# %%
q_results = []
standard_gain_differences = []

instances_indexes = range(5)
for file_index,(filename,data2) in enumerate(files.items()):
    q_results.append([])
    standard_gain_differences.append([])
    
    for instance_index in instances_indexes:
        #q_result =  QAOAResult.from_dict(data2[str(instance_index)]['result'])
        # q_results[file_index].append(
        #      q_result
        # )
        standard_gain_differences[file_index].append(data2[str(instance_index)]['standard_gain_difference'])
standard_gain_differences = np.array(standard_gain_differences)

# %%
# Create a bar plot
fig, ax = plt.subplots(figsize=(14, 4))
markers = ['o', '^', 's', 'D', 'p']  
linestyles = ['-', '--', '-.', ':']  
bar_width = 0.5
category_width = 3  

if SAVE_IN_ENGLISH:
    xlabel = 'Configuration (n_agents, n_vacantJobs, p)'
    ylabel = 'Standard gain difference'
    title = 'Standard gain difference for the JRP instances of all configurations'
    legend_elements = [plt.Line2D([0], [0], marker=markers[i], color='w', label=f'Instance {i+1}', 
                              markerfacecolor='k', markersize=10) for i in range(num_samples_per_file)]
    save_dir = "results/standard_gain/standard_gain_per_instance"
else:
    xlabel = 'Configuración (n_trabajadores, n_puestosVacantes, p)'
    ylabel = 'Diferencia de ganancia\nde la función estandar'
    title = 'Diferencia de ganancia de la función estandar para las instancias JRP de todas las configuraciones'
    legend_elements = [plt.Line2D([0], [0], marker=markers[i], color='w', label=f'Instancia {i+1}', 
                              markerfacecolor='k', markersize=10) for i in range(num_samples_per_file)]
    save_dir = "../../spanish_imgs/notebooks/results/standard_gain/standard_gain_per_instance"

# Plot bars for each group
for i in range(num_samples_per_file):
    for j in range(0,first_files):
        ax.plot(np.arange(first_files)[j] * category_width  + i * bar_width / num_samples_per_file,  # Desplazamiento de los puntos
            standard_gain_differences[j, i],
            'o', 
            color=colors[j][i],
            marker=markers[i],
            markersize=10,
            label=f'Group {i+1}'
               ,markeredgewidth=2,  
            markeredgecolor='black')

# Add labels, title, and legend
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)
ax.legend(handles=legend_elements,  loc='upper left', bbox_to_anchor=(1, 1),handletextpad=0.01)
plt.xticks(np.arange(first_files) * category_width  + bar_width / 2, labels=[f'{configurations_names[i]}' for i in range(first_files)])
plt.tight_layout()
plt.savefig(save_dir+"/1.png", bbox_inches='tight')  # Guardar la figura en un archivo
plt.show()

fig, ax = plt.subplots(figsize=(14, 4))
for i in range(num_samples_per_file):
    for j in range(last_files):
        ax.plot(np.arange(last_files)[j] * category_width  + i * bar_width / num_samples_per_file, 
            standard_gain_differences[first_files+j, i],
            'o', 
            color=colors[j][i],
            marker=markers[i],
            markersize=10,
            label=f'Group {i+1}',
               markeredgewidth=2,  
            markeredgecolor='black')

# Add labels, title, and legend
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)
ax.legend(handles=legend_elements,  loc='upper left', bbox_to_anchor=(1, 1),handletextpad=0.01)


plt.xticks(np.arange(last_files) * category_width  + bar_width / 2, [f'{configurations_names[i]}' for i in  range(last_files-1,nums_files)])
#ax.set_yticks(np.arange(0, 1.1, 0.1) )
plt.tight_layout()
plt.savefig(save_dir+"/2.png", bbox_inches='tight')  # Guardar la figura en un archivo
plt.show()
# Out:
# C:\Users\Adriano\AppData\Local\Temp\ipykernel_4356\4173503438.py:26: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(np.arange(first_files)[j] * category_width  + i * bar_width / num_samples_per_file,  # Desplazamiento de los puntos
# C:\Users\Adriano\AppData\Local\Temp\ipykernel_4356\4173503438.py:48: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(np.arange(last_files)[j] * category_width  + i * bar_width / num_samples_per_file,

# %%
column_names = ['Instance 1', 'Instance 2', 'Instance 3', 'Instance 4', 'Instance 5']
df = pd.DataFrame(standard_gain_differences,columns=column_names)
df.insert(0,'configuration',configurations_names)
df.to_csv('results/csvs/standard_gain_differences/standard_gain_differences_per_configuration.csv')

# %%
aux = standard_gain_differences.flatten()
diffs = np.array(aux[:90])
diffs = diffs.reshape((3, 30)).tolist()
diffs.insert(1,aux[90:])
diffs.insert(0,aux)

means = [np.mean(sbf, axis=0) for sbf in diffs]

plt.figure(figsize=(6, 4))

if SAVE_IN_ENGLISH:
    plt.xlabel('Problem size')
    plt.ylabel('Standard gain difference')
    categories =  ['all samples',15,16,18,20]
    save_dir = "results/standard_gain/standard_gain_per_problemsize.png"
else:
    plt.xlabel('Tamaño del problema')
    plt.ylabel('Diferencia de ganancia\nde la función estandar')
    categories =  ['todas las\nmuestras',15,16,18,20]
    save_dir = "../../spanish_imgs/notebooks/results/standard_gain/standard_gain_per_problemsize.png"

boxplot_stats=plt.boxplot(diffs,labels=categories,usermedians=means)
plt.savefig(save_dir, bbox_inches='tight')  # Guardar la figura en un archivo
plt.show()

# %%
num_categories =len(categories)
statistics = np.zeros((num_categories, 5))  
for i in range(num_categories):
    # Boxplot stats
    box = boxplot_stats['boxes'][i].get_ydata()
    whiskers = boxplot_stats['whiskers'][2*i:2*i+2]
    means = boxplot_stats['medians'][i].get_ydata()
    caps = boxplot_stats['caps'][2*i:2*i+2]
    
    # Agregar estadísticas
    statistics[i, 0] = round(means[1],3)  # Mediana
    statistics[i, 1] = round(box[0],3)    # 25th percentile
    statistics[i, 2] =round(box[2],3)      # 75th percentile
    statistics[i, 3] = round(whiskers[0].get_ydata()[1],3)  # Bigote inferior
    statistics[i, 4] = round(whiskers[1].get_ydata()[1],3) # Bigote superior


column_names = ['mean','q1','q3','min.','max.']
df = pd.DataFrame(statistics[1:][:],columns=column_names)
df.insert(0,'problem size',[15,16,18,20])
df.to_csv('results/csvs/standard_gain_differences/standard_gain_differences_per_problem_size.csv')

# %%
#subdatas = [data.flatten()]
diffs = [aux]
for index in range(0,3):
    aux2 = np.array([])
    for index2 in range(0,21,3):
        aux2=np.concatenate((aux2,standard_gain_differences[index+index2]))
    diffs.append(aux2)
means = [np.mean(sbf, axis=0) for sbf in diffs]

plt.figure(figsize=(6, 4))

if SAVE_IN_ENGLISH:
    plt.xlabel('p')
    plt.ylabel('Standard gain difference')
    categories =  ['all samples',3,4,5]
    save_dir = "results/standard_gain/standard_gain_per_p.png"
else:
    plt.xlabel('p')
    plt.ylabel('Diferencia de ganancia\nde la función estandar')
    categories =  ['todas las\nmuestras',3,4,5]
    save_dir = "../../spanish_imgs/notebooks/results/standard_gain/standard_gain_per_p.png"

boxplot_stats=plt.boxplot(diffs,labels=categories,usermedians=means)
plt.savefig(save_dir, bbox_inches='tight')  # Guardar la figura en un archivo
plt.show()

# %%
num_categories =len(categories)
statistics = np.zeros((num_categories, 5))  
for i in range(num_categories):
    # Boxplot stats
    box = boxplot_stats['boxes'][i].get_ydata()
    whiskers = boxplot_stats['whiskers'][2*i:2*i+2]
    means = boxplot_stats['medians'][i].get_ydata()
    caps = boxplot_stats['caps'][2*i:2*i+2]
    
    # Agregar estadísticas
    statistics[i, 0] = round(means[1],3)  # Mediana
    statistics[i, 1] = round(box[0],3)    # 25th percentile
    statistics[i, 2] =round(box[2],3)      # 75th percentile
    statistics[i, 3] = round(whiskers[0].get_ydata()[1],3)  # Bigote inferior
    statistics[i, 4] = round(whiskers[1].get_ydata()[1],3) # Bigote superior


column_names = ['mean','q1','q3','min.','max.']
df = pd.DataFrame(statistics[1:][:],columns=column_names)
df.insert(0,'problem size',[3,4,5])
df.to_csv('results/csvs/standard_gain_differences/standard_gain_differences_per_p.csv')

# %% [markdown]
# ### Probability of measuring with a minimal approximation ratio and number of shots

# %% [markdown]
# In this section, the idea is to draw some contour plots, where a point (X,Y,Z), where Z is representes a color depth, means the following:
#
# "After doing Y measures of the ansatz with the optimized parameters,  there is a probability of Z that one of that measured solutions has   an approximation ratio of X or bigger"

# %% [markdown]
# Two types of processing will be done. First, a process for a regular sampling. That is that for the first sampling done, where we estimate the bitstring probabilities for $Y=1$, we use a prefixed 10000 shots.
#
# On other hand, for the "too big" sampling, we use much more shots. In particular, the number of shots are:
# * for JRP confs. of $n=15$ qubits, $1500 \cdot 2^n$ shots.
# * for JRP confs. of $n=16$ qubits, $800 \cdot 2^n$ shots.
# * for JRP confs. of $n=18$ qubits, $200 \cdot 2^n$ shots.
# * for JRP confs. of $n=20$ qubits, $50 \cdot 2^n$ shots.
#
#
# This products result in approximately 50000000 shots. This second sampling is way too cost and was done and was done with secondary purposes. While the results are available at $\texttt{results/contourf\_plots/too\_big\_sampling}$ directory, they won't be used further in this project.

# %%
def tensor3_for_approximation_ratio(file,circuit_configuration,q_result=None,create_cost_hamiltonian_object=True,
                                         size=5000,n_shots_to_sample=10000,n_samples=1000,
                                         n_shots_to_extrapolate=100,directory=None,plot=False):
    '''
    creates a 3-tensor where, a point (X,Y,Z) is interpretated as follows:
    "After doing Z measures of the ansatz with the optimized parameters,
    there is a probability of Y that one of that measured solutions has
    an approximation ratio of X or bigger"

    Parameters:
        - file
            a dictionary representing a json file from a TestQAOASolver experiment
        - q_result
        - create_cost_hamiltonian_object
        - size
        - n_shots_to_sample
        - n_shots_to_extrapolate
        - directory
    '''
    # STEP 1: PARAMETERS CONTROLS
    # if the QAOAResult object is not given, it is taken from the json file
    if q_result is None:
        q_result = QAOAResult.from_dict(file['result'])
    # if it is indicated to create the Hamiltonian object for the cost hamiltonian
    if create_cost_hamiltonian_object:
        q_result.cost_hamiltonian = hamiltonian_from_dict(q_result.cost_hamiltonian)

    # STEP 2: THE JRP IN ISING FORMULATION IS RECREATED.
    q_solver = QAOASolver()
    instance_dict = file["instance"]
    current_jrp = JRPClassic(instance_dict)
    jrp_ising = q_solver.get_jrp_ising(current_jrp)

    # STEP 3: A QAOA SOLVER IS CONFIGURED FOR SAMPLING 'n_shot_to_samples' SHOTS.
    device = create_device(location='local', name='qiskit.shot_simulator')
    qaoa = QAOA()
    qaoa.set_device(device)
    qaoa.set_circuit_properties(**circuit_configuration)
    qaoa.set_backend_properties(n_shots= n_shots_to_sample)
    qaoa.compile(jrp_ising)
        
    # STEP 4: THE MEASUREMENTS OUTCUMES OF THE Q_RESULT ARE REPLACED WITH THE NEW ONES
    new_measurement_outcomes = qaoa.evaluate_circuit(file['result']['optimized']['angles'])['measurement_results']          
    q_result.optimized["measurement_outcomes"] = new_measurement_outcomes

    # STEP 2: INITIALIZE IMPORTANT VARIABLES
    #   - 'size' lowest cost bitstrings, in Ising formulation
    solutions_bitstring = q_result.lowest_cost_bitstrings(size)['solutions_bitstrings']
    print(q_result.lowest_cost_bitstrings(size))
    #   - probabilities of measuring each of the bitstring
    probabilities = q_result.lowest_cost_bitstrings(size)['probabilities']
    #   - the JRP instance
    instance =  JRPClassic(file['instance'])
    #   - the gain of the optimal standard solution
    optimal_standard_solution_gain = instance.calculate_standard_gain(file['opt_standard_solution'])

    # STEP 3: CONVERTS ISING SOLUTIONS TO STANDARD ONES AND CALCULATE ITS PROBABILITIES VARIANCES
    standard_solutions = []
    aux_probabilities = []
    variances = {}
    mean_variance = []
    for s,p in zip(solutions_bitstring,probabilities):
        try:
            # if the method raise an error, means that the solution is unfeasible, so it won't be appended to final list
            ss=instance.quboSolution_to_standardSolution(s,check_feasibility=True)
            standard_solutions.append(ss)
            aux_probabilities.append(p)
            variances[s] = round(p * (1 - p) * n_shots_to_sample,15)
        except:
            pass
    mean_variance = sum(variances.values()) / len(variances)
    probabilities = aux_probabilities

    # STEP 4: CALCULATE THE APPROXIMATION RATIOS FOR EACH LOWEST STANDARD SOLUTION
    approximation_ratios = []
    for s in standard_solutions:
        approx_ratio = instance.calculate_standard_gain(s)/optimal_standard_solution_gain
        approximation_ratios.append(round(approx_ratio,4))

    # STEP 5: SUM UP PROBABILITIES OF REPEATED APPROXIMATION RATIOS
    aux_dict = {}
    for ar,p in zip(approximation_ratios,probabilities):
        # if an aaproximation ratio is alredy in the dictionary, it won't replace the key value, instead, it will sum up the new probability
        if str(ar) in aux_dict.keys():
            aux_dict[str(ar)] = aux_dict[str(ar)] + p
        # else, it will initializate with the new probability
        else:
            aux_dict[str(ar)] = p
    approximation_ratios = [float(i) for i in list(aux_dict.keys())]
    probabilities = list(aux_dict.values())

    # STEP 6: calculate the Complementary Cumulative Distribution Function over the probabilities
    # https://en.wikipedia.org/wiki/Cumulative_distribution_function#Complementary_cumulative_distribution_function_(tail_distribution)
    ccdf = []
    for index in range(len(probabilities)):
        ccdf.append(round(np.sum(np.array(probabilities[:index+1])),4))

    # STEP 7: expand the ccdf for over n measures
    measures = range(n_shots_to_extrapolate)
    array_3D = np.zeros((n_shots_to_extrapolate, len(ccdf)))
    for i in range(array_3D.shape[0]):
        for j in range(array_3D.shape[1]):
            array_3D[i,j] = 1-(1-ccdf[j])** measures[i]

    # STEP 8: final plot
    X = approximation_ratios  
    Z = measures  
    Y = array_3D

    axis = {
        'X':X,
        'Z':list(Z),
        'Y':Y.tolist(),
        'one_measurement_probabilities_variances':variances,
        'one_measurement_probabilities_mean_variances':mean_variance
    }
    with open(directory, 'w') as f:
        json.dump(axis, f)

    if plot:
        make_contourf_plot(X,Y,Z)
    
    # creates a dataframe to return
    df = pd.DataFrame(Y.transpose())
    df.index = X
    df.index.name = 'min. approx.ratio expected'
    df.columns = list(Z)
    df.columns.name = 'measurements'
    return df

# %%
from collections import defaultdict
import time


# MUESTREO SIN BOOTSTRAPING,SAMPLEO NORMAL
def tensor3_for_approximation_ratio(file,circuit_configuration,q_result=None,create_cost_hamiltonian_object=True,
                                         size=5000,n_shots_to_sample=10000,n_samples=1000,
                                         n_shots_to_extrapolate=100,directory=None,plot=False):
    '''
    creates a 3-tensor where, a point (X,Y,Z) is interpretated as follows:
    "After doing Z measures of the ansatz with the optimized parameters,
    there is a probability of Y that one of that measured solutions has
    an approximation ratio of X or bigger"

    Parameters:
        - file
            a dictionary representing a json file from a TestQAOASolver experiment
        - q_result
        - create_cost_hamiltonian_object
        - size
        - n_shots_to_sample
        - n_shots_to_extrapolate
        - directory
    '''
    # STEP 1: PARAMETERS CONTROLS
    # if the QAOAResult object is not given, it is taken from the json file
    if q_result is None:
        q_result = QAOAResult.from_dict(file['result'])
    # if it is indicated to create the Hamiltonian object for the cost hamiltonian
    if create_cost_hamiltonian_object:
        q_result.cost_hamiltonian = hamiltonian_from_dict(q_result.cost_hamiltonian)

    # STEP 2: THE JRP IN ISING FORMULATION IS RECREATED.
    q_solver = QAOASolver()
    instance_dict = file["instance"]
    current_jrp = JRPClassic(instance_dict)
    jrp_ising = q_solver.get_jrp_ising(current_jrp)

    # STEP 3: A QAOA SOLVER IS CONFIGURED FOR SAMPLING 'n_shot_to_samples' SHOTS.
    device = create_device(location='local', name='qiskit.shot_simulator')
    qaoa = QAOA()
    qaoa.set_device(device)
    qaoa.set_circuit_properties(**circuit_configuration)
    qaoa.set_backend_properties(n_shots= n_shots_to_sample)
    qaoa.compile(jrp_ising)

    solutions_probabilities = defaultdict(float)
    samples_solutions_probabilities = []
    the_time = time.time()
    for sample in range(n_samples):
        print('sample',sample)
        # STEP 4: THE MEASUREMENTS OUTCUMES OF THE Q_RESULT ARE REPLACED WITH THE NEW ONES
        new_measurement_outcomes = qaoa.evaluate_circuit(file['result']['optimized']['angles'])['measurement_results']          
        q_result.optimized["measurement_outcomes"] = new_measurement_outcomes

        # STEP 2: INITIALIZE IMPORTANT VARIABLES
        #   - 'size' lowest cost bitstrings, in Ising formulation
        aux_data = q_result.lowest_cost_bitstrings(size)
        aux_solutions_bitstring = aux_data['solutions_bitstrings']
        aux_probabilities = aux_data['probabilities']
        #aux_solutions_bitstring = q_result.lowest_cost_bitstrings(size)['solutions_bitstrings']
        #   - probabilities of measuring each of the bitstring
        #aux_probabilities = q_result.lowest_cost_bitstrings(size)['probabilities']
        aux_solutions_probabilities = dict(zip(aux_solutions_bitstring,aux_probabilities))
        samples_solutions_probabilities.append(aux_solutions_probabilities)
        
        for key,value in aux_solutions_probabilities.items():
            solutions_probabilities[key] += value
            #if key in solutions_probabilities:
            #    solutions_probabilities[key] += value
            #else:
            #    solutions_probabilities[key] = value
    solutions_bitstring = list(solutions_probabilities.keys())
    probabilities =[prob / n_samples for prob in list(solutions_probabilities.values())]
    the_time = time.time() - the_time
    print('TIME:',the_time)
    #   - the JRP instance
    instance =  JRPClassic(file['instance'])
    #   - the gain of the optimal standard solution
    optimal_standard_solution_gain = instance.calculate_standard_gain(file['opt_standard_solution'])

    # STEP 3: CONVERTS ISING SOLUTIONS TO STANDARD ONES AND CALCULATE ITS PROBABILITIES VARIANCES
    standard_solutions = []
    aux_probabilities = []
    variances = {}
    mean_variance = []
    for s,p in zip(solutions_bitstring,probabilities):
        try:
            # if the method raise an error, means that the solution is unfeasible, so it won't be appended to final list
            ss=instance.quboSolution_to_standardSolution(s,check_feasibility=True)
            standard_solutions.append(ss)
            aux_probabilities.append(p)
            #variances[s] = round(p * (1 - p) * n_shots_to_sample,15) # this follows the theoretical multinomial distriubtion variance, i should ise the sample variance
            sumatory = 0
            for ssp in samples_solutions_probabilities:
                sample_estimated_p = ssp[s] if s in ssp.keys() else 0
                sumatory += (sample_estimated_p - p)**2
            variances[s] = sumatory / (n_samples-1)
        except:
            pass
    mean_variance = sum(variances.values()) / len(variances)
    probabilities = aux_probabilities

    # STEP 4: CALCULATE THE APPROXIMATION RATIOS FOR EACH LOWEST STANDARD SOLUTION
    approximation_ratios = []
    for s in standard_solutions:
        approx_ratio = instance.calculate_standard_gain(s)/optimal_standard_solution_gain
        approximation_ratios.append(round(approx_ratio,4))

    # STEP 5: SUM UP PROBABILITIES OF REPEATED APPROXIMATION RATIOS
    aux_dict = {}
    for ar,p in zip(approximation_ratios,probabilities):
        # if an aaproximation ratio is alredy in the dictionary, it won't replace the key value, instead, it will sum up the new probability
        if str(ar) in aux_dict.keys():
            aux_dict[str(ar)] = aux_dict[str(ar)] + p
        # else, it will initializate with the new probability
        else:
            aux_dict[str(ar)] = p
    approximation_ratios = [float(i) for i in list(aux_dict.keys())]
    probabilities = list(aux_dict.values())

    # STEP 6: calculate the Complementary Cumulative Distribution Function over the probabilities
    # https://en.wikipedia.org/wiki/Cumulative_distribution_function#Complementary_cumulative_distribution_function_(tail_distribution)
    ccdf = []
    for index in range(len(probabilities)):
        ccdf.append(round(np.sum(np.array(probabilities[:index+1])),4))

    # STEP 7: expand the ccdf for over n measures
    measures = range(n_shots_to_extrapolate)
    array_3D = np.zeros((n_shots_to_extrapolate, len(ccdf)))
    for i in range(array_3D.shape[0]):
        for j in range(array_3D.shape[1]):
            array_3D[i,j] = 1-(1-ccdf[j])** measures[i]

    # STEP 8: final plot
    X = approximation_ratios  
    Z = measures  
    Y = array_3D

    axis = {
        'X':X,
        'Z':list(Z),
        'Y':Y.tolist(),
        'one_measurement_probabilities_variances':variances,
        'one_measurement_probabilities_mean_variances':mean_variance
    }
    with open(directory, 'w') as f:
        json.dump(axis, f)

    if plot:
        make_contourf_plot(X,Y,Z)
    
    # creates a dataframe to return
    df = pd.DataFrame(Y.transpose())
    df.index = X
    df.index.name = 'min. approx.ratio expected'
    df.columns = list(Z)
    df.columns.name = 'measurements'
    return df

# %%
from collections import defaultdict
import time
import math

# MUESTREO CON BOOTSTRAPING
def tensor3_for_approximation_ratio(file,circuit_configuration,q_result=None,create_cost_hamiltonian_object=True,
                                         size=5000,n_shots_for_original_sample=10000,n_bootstraps=1000,
                                         n_shots_to_extrapolate=100,directory=None,plot=False):
    '''
    creates a 3-tensor where, a point (X,Y,Z) is interpretated as follows:
    "After doing Z measures of the ansatz with the optimized parameters,
    there is a probability of Y that one of that measured solutions has
    an approximation ratio of X or bigger"

    Parameters:
        - file
            a dictionary representing a json file from a TestQAOASolver experiment
        - q_result
        - create_cost_hamiltonian_object
        - size
        - n_shots_for_original_sample
        - n_shots_to_extrapolate
        - directory
    '''
    # STEP 1: PARAMETERS CONTROLS
    # if the QAOAResult object is not given, it is taken from the json file
    if q_result is None:
        q_result = QAOAResult.from_dict(file['result'])
    # if it is indicated to create the Hamiltonian object for the cost hamiltonian
    if create_cost_hamiltonian_object:
        q_result.cost_hamiltonian = hamiltonian_from_dict(q_result.cost_hamiltonian)

    # STEP 2: THE JRP IN ISING FORMULATION IS RECREATED.
    q_solver = QAOASolver()
    instance_dict = file["instance"]
    current_jrp = JRPClassic(instance_dict)
    jrp_ising = q_solver.get_jrp_ising(current_jrp)

    # STEP 3: A QAOA SOLVER IS CONFIGURED FOR SAMPLING 'n_shots_for_original_sample' SHOTS.
    device = create_device(location='local', name='qiskit.shot_simulator')
    qaoa = QAOA()
    qaoa.set_device(device)
    qaoa.set_circuit_properties(**circuit_configuration)
    qaoa.set_backend_properties(n_shots= n_shots_for_original_sample)
    qaoa.compile(jrp_ising)

    # STEP 4: THE ORIGINAL SAMPLE FOR THE BOOTSTRAP IS TAKEN
    print('4')
    original_measurement_outcomes = qaoa.evaluate_circuit(file['result']['optimized']['angles'])['measurement_results']          
    
    the_time = time.time() 
    solutions_probabilities = defaultdict(float) # list for saving the sumed probabilities of bootstrap. Used for calculating mean proportions.
    bootstrap_solutions_probabilities = [] # list for saving the bootstraps
    keys = list(original_measurement_outcomes.keys()) # the keys are the bitstrings measured in the original sample
    probabilities = [freq / sum(original_measurement_outcomes.values()) for freq in original_measurement_outcomes.values()] 
    # each original sample bitstring frequency is passed to probability
    
    # STEP 5: BOOTSTRAP SAMPLING
    print('5')
    for sample in range(n_bootstraps):
        # STEP 5.1: THE BOOTSTRAP IS CREATED
        print('sample',sample,end='\r')
        bootstrap_measurement_outcomes = np.random.choice(keys,
                                                          size=n_shots_for_original_sample,
                                                          replace=True,
                                                          p=probabilities # this bias the choice prob. according to the frequency a bitstring was measured
                                                         )
        bootstrap_measurement_outcomes = dict(Counter(bootstrap_measurement_outcomes)) # the bootstrap sample is saved as OpenQAOA require (bitstring,freq.)
        q_result.optimized["measurement_outcomes"] = bootstrap_measurement_outcomes

        # STEP 5.2: FROM THE BOOTSTRAP, JUST THE 'SIZE' FIRST BITSTRINGS ARE CONSIDERED
        aux_data = q_result.lowest_cost_bitstrings(size)
        aux_solutions_bitstring = aux_data['solutions_bitstrings']
        aux_probabilities = aux_data['probabilities']

        # STEP 5.3: THE 'SIZE'-FILTERED BOOTSTRAP IS SAVED
        aux_solutions_probabilities = dict(zip(aux_solutions_bitstring,aux_probabilities))
        bootstrap_solutions_probabilities.append(aux_solutions_probabilities)

        # STEP 5.4: THE PROBABILITIES ARE SUMED IN THE GENERAL DATA STRUCTURE (USED FOR CALCULATING MEAN PROPORTIONS)
        for key,value in aux_solutions_probabilities.items():
            solutions_probabilities[key] += value

    # STEP 6: THE MEAN PROPORTIONS ARE CALCULATED
    solutions_bitstring = list(solutions_probabilities.keys())
    probabilities =[prob / n_bootstraps for prob in list(solutions_probabilities.values())]
    the_time = time.time() - the_time
    print('TIME:',the_time)

    # STEP 7: SOME IMPORTANT VARIABLES ARE CREATED
    #   - the JRP instance
    instance =  JRPClassic(file['instance'])
    #   - the gain of the optimal standard solution
    optimal_standard_solution_gain = instance.calculate_standard_gain(file['opt_standard_solution'])

    # STEP 8: CONVERTS ISING SOLUTIONS TO STANDARD ONES AND CALCULATE THE PROPORTIONS VARIANCES AND ERROR MARGINS (FOR CONFIDENCE INTRV.)
    standard_solutions = []
    aux_probabilities = []
    variances = {}
    confidenceinterval_errormargins = {}
    confidenceinterval_points = {}
    for s,p in zip(solutions_bitstring,probabilities):
        try:
            # STEP 8.1: CONVERT ISING TO STANDARD
            # if the method raise an error, means that the solution is unfeasible, so it won't be appended to final list
            ss=instance.quboSolution_to_standardSolution(s,check_feasibility=True)
            standard_solutions.append(ss)
            aux_probabilities.append(p)
            confidenceinterval_points[s] = p

            # STEP 8.2 CALCULATE VARIANCES AND ERROR MARGINS
            sumatory = 0
            for bsp in bootstrap_solutions_probabilities:
                bootstrap_estimated_p = bsp[s] if s in bsp.keys() else 0
                sumatory += (bootstrap_estimated_p - p)**2
            variances[s] = sumatory / (n_bootstraps-1)
            confidenceinterval_errormargins[s] = math.sqrt(variances[s])
        except:
            pass
    mean_variance = sum(variances.values()) / len(variances)
    probabilities = aux_probabilities    

    # STEP 9: CALCULATE THE APPROXIMATION RATIOS FOR EACH LOWEST STANDARD SOLUTION
    approximation_ratios = []
    for s in standard_solutions:
        approx_ratio = instance.calculate_standard_gain(s)/optimal_standard_solution_gain
        approximation_ratios.append(round(approx_ratio,4))

    # STEP 10: SUM UP PROBABILITIES OF REPEATED APPROXIMATION RATIOS
    aux_dict = {}
    for ar,p in zip(approximation_ratios,probabilities):
        # if an aaproximation ratio is alredy in the dictionary, it won't replace the key value, instead, it will sum up the new probability
        if str(ar) in aux_dict.keys():
            aux_dict[str(ar)] = aux_dict[str(ar)] + p
        # else, it will initializate with the new probability
        else:
            aux_dict[str(ar)] = p
    approximation_ratios = [float(i) for i in list(aux_dict.keys())]
    probabilities = list(aux_dict.values())

    # STEP 11: calculate the Complementary Cumulative Distribution Function over the probabilities
    # https://en.wikipedia.org/wiki/Cumulative_distribution_function#Complementary_cumulative_distribution_function_(tail_distribution)
    ccdf = []
    for index in range(len(probabilities)):
        ccdf.append(round(np.sum(np.array(probabilities[:index+1])),4))

    # STEP 12: expand the ccdf for over n measures
    measures = range(n_shots_to_extrapolate)
    array_3D = np.zeros((n_shots_to_extrapolate, len(ccdf)))
    for i in range(array_3D.shape[0]):
        for j in range(array_3D.shape[1]):
            array_3D[i,j] = 1-(1-ccdf[j])** measures[i]

    # STEP 13: final plot
    X = approximation_ratios  
    Z = measures  
    Y = array_3D

    axis = {
        'n_shots_for_original_sample':n_shots_for_original_sample,
        'n_bootstraps':n_bootstraps,
        'n_shots_to_extrapolate':n_shots_to_extrapolate,
        'size':size,
        'X':X,
        'Z':list(Z),
        'Y':Y.tolist(),
        'sample_variances':variances,
        'mean_sample_variances':mean_variance,
        'confidenceInterval_points':confidenceinterval_points,
        'confidenceInterval_errormargins':confidenceinterval_errormargins
    }
    with open(directory, 'w') as f:
        json.dump(axis, f)

    if plot:
        make_contourf_plot(X,Y,Z)
    
    # creates a dataframe to return
    df = pd.DataFrame(Y.transpose())
    df.index = X
    df.index.name = 'min. approx.ratio expected'
    df.columns = list(Z)
    df.columns.name = 'measurements'
    return df

# %%
import scipy.interpolate as interp

def tensor3_for_approximation_ratio(file,circuit_configuration,q_result=None,create_cost_hamiltonian_object=True,
                                         size=5000,n_bootstraps = 1000,n_shots_for_original_sample=10000,
                                         n_shots_to_extrapolate=100,directory=None,plot=False):
    '''
    creates a 3-tensor where, a point (X,Y,Z) is interpretated as follows:
    "After doing Z measures of the ansatz with the optimized parameters,
    there is a probability of Y that one of that measured solutions has
    an approximation ratio of X or bigger"

    Parameters:
        - file
            a dictionary representing a json file from a TestQAOASolver experiment
        - q_result
        - create_cost_hamiltonian_object
        - size
        - n_shots_to_sample
        - n_shots_to_extrapolate
        - directory
    '''
    # STEP 1: PARAMETERS CONTROLS
    # if the QAOAResult object is not given, it is taken from the json file
    if q_result is None:
        q_result = QAOAResult.from_dict(file['result'])
    # if it is indicated to create the Hamiltonian object for the cost hamiltonian
    if create_cost_hamiltonian_object:
        q_result.cost_hamiltonian = hamiltonian_from_dict(q_result.cost_hamiltonian)

    # STEP 2: THE JRP IN ISING FORMULATION IS RECREATED.
    q_solver = QAOASolver()
    instance_dict = file["instance"]
    current_jrp = JRPClassic(instance_dict)
    jrp_ising = q_solver.get_jrp_ising(current_jrp)
    
    # SET QAOA
    device = create_device(location='local', name='qiskit.shot_simulator')
    qaoa = QAOA()
    qaoa.set_device(device)
    qaoa.set_circuit_properties(**circuit_configuration)
    qaoa.set_backend_properties(n_shots= n_shots_for_original_sample)
    qaoa.compile(jrp_ising)


    # GENERAL PARAMS
    #   - the JRP instance
    instance =  JRPClassic(file['instance'])
    #   - the gain of the optimal standard solution
    optimal_standard_solution_gain = instance.calculate_standard_gain(file['opt_standard_solution'])
    
    # DO ORIGINAL SAMPLE
    original_sample = qaoa.evaluate_circuit(file['result']['optimized']['angles'])['measurement_results']          
    keys = list(original_sample.keys()) # the keys are the bitstrings measured in the original sample
    probabilities = [freq / sum(original_sample.values()) for freq in original_sample.values()]

    bootstrap_dfs = []
    for i in range(n_bootstraps):
        print('taking bootstrap',i)
        bootstrap = aux_tensor3_for_approximation_ratio(original_sample
                                            ,instance,keys
                                            ,probabilities
                                            ,optimal_standard_solution_gain
                                            ,q_result
                                            ,n_shots_to_extrapolate=n_shots_to_extrapolate
                                           ,plot=plot)
        bootstrap_dfs.append(bootstrap)
    
    # Verificar si todos los bootstraps son idénticos
    if all(bootstrap.equals(bootstrap_dfs[0]) for bootstrap in bootstrap_dfs):
        print("Warning: All bootstrap samples are identical. Check sampling procedure.")
    
    # Reorganizar los datos: agrupar todas las columnas equivalentes entre los bootstraps
    n_ccdfs = bootstrap_dfs[0].shape[1]  # Número de CCDFs por bootstrap
    means = []
    errormargins = []
    confidence_intervals = []

    for i in range(n_ccdfs):
        print('postprocessing CCDF',i)
        interpolated_bootstraps = []
        
        for j,df in enumerate(bootstrap_dfs):
            x_values, interpolated_df = interpolate_ccdf(df.iloc[:, [i]])
            if j == 0:
                pass
                #display(df.iloc[:, [i]])
                #display(interpolated_df)
            #plot_ccdf_with_ci(x_values, interpolated_df, title=f'xd {i}')
            interpolated_bootstraps.append(interpolated_df)
        
        #bootstrap_i = pd.concat(interpolated_bootstraps, axis=1)
        x, mean_ccdf, errormargin = bootstrap_confidence_intervals(interpolated_bootstraps)
        
        #print(f'CCDF {i}: Mean min={mean_ccdf.min()}, max={mean_ccdf.max()}')
        #print(f'Lower min={lower.min()}, max={lower.max()}')
        #print(f'Upper min={upper.min()}, max={upper.max()}')
        #print(f'Sample lower: {lower[:5].values}')
        #print(f'Sample upper: {upper[:5].values}')

        means.append(mean_ccdf)
        errormargins.append(errormargin)
        #confidence_intervals.append((x, mean_ccdf, errormargin))
    X = list(x)
    Z = list(range(n_shots_to_extrapolate))
    Y_mean = [m.tolist() for m in means]
    Y_errormargin = [e.tolist() for e in errormargins]
    axis = {
        'X':X,
        'Z':Z,
        'Y_mean':Y_mean,
        'Y_errormargin':Y_errormargin
    }
    with open(directory, 'w') as f:
        json.dump(axis, f)
        
    means_df = pd.DataFrame(np.array(means).transpose())
    errormargins_df = pd.DataFrame(np.array(errormargins).transpose())
    means_df.index = x
    means_df.index.name = 'min. approx.ratio expected'
    means_df.columns = range(n_shots_to_extrapolate)
    means_df.columns.name = 'measurements'
    errormargins_df.index = x
    errormargins_df.index.name = 'min. approx.ratio expected'
    errormargins_df.columns = range(n_shots_to_extrapolate)
    errormargins_df.columns.name = 'measurements'
    return means_df,errormargins_df
    
    #display(means_df)
    #display(errormargins_df)
    #for i, (mean_ccdf,errormargin) in enumerate(zip(means,errormargins)):
    #    plot_ccdf_with_ci(x, mean_ccdf, errormargin, title=f'Bootstrap CCDF {i} with Confidence Interval')

def interpolate_ccdf(df):
    x_values = np.linspace(df.index.min(), df.index.max(), 300)
    interpolated_ccdfs = {}
    
    for col in df.columns:
        f = interp.interp1d(df.index, df[col], kind='linear', fill_value=(1, 0), bounds_error=False)
        interpolated_ccdfs[col] = f(x_values)
    
    return x_values, pd.DataFrame(interpolated_ccdfs, index=x_values)

def bootstrap_confidence_intervals(bootstraps, alpha=0.05):
    # Apilar todas las matrices de bootstrap para obtener un arreglo 3D
    bootstraps_stack = np.stack(bootstraps, axis=0)  # Crea un tensor 3D (n, m, m)
    
    # Calcular la media a lo largo de los bootstraps (axis=0) para cada posición (i,j)
    mean_ccdf = bootstraps_stack.mean(axis=0).flatten()
    
    # Calcular los percentiles para los intervalos de confianza
    lower_bound = np.percentile(bootstraps_stack, alpha/2 * 100, axis=0).flatten()  # Percentil inferior
    upper_bound = np.percentile(bootstraps_stack, (1 - alpha/2) * 100, axis=0).flatten()  # Percentil superior
    errormargin = (upper_bound - lower_bound) / 2
    
    return bootstraps[0].index, mean_ccdf, errormargin

def plot_ccdf_with_ci(x, mean_ccdf, errormargin, title='Bootstrap CCDF with Confidence Interval'):
    # Limpia el gráfico anterior
    plt.clf()
    
    # Configura la figura
    plt.figure(figsize=(8, 5))
    
    # Grafica los datos
    plt.plot(x, mean_ccdf, label='Mean CCDF', color='blue')
    plt.fill_between(x, mean_ccdf-errormargin, mean_ccdf+errormargin, color='blue', alpha=0.4, label='90% CI', edgecolor='none')

    # Añadir etiquetas y título
    plt.xlabel('Min Approximation Ratio')
    plt.ylabel('CCDF')
    plt.title(title)
    
    # Mostrar la leyenda y el grid
    plt.legend()
    plt.grid()
    
    # Mostrar el gráfico
    plt.show()

def aux_tensor3_for_approximation_ratio(original_sample,instance,keys,probabilities,optimal_standard_solution_gain,q_result,
                                         size=5000,
                                         n_shots_to_extrapolate=100,directory=None,plot=False):



    # STEP 3: A QAOA SOLVER IS CONFIGURED FOR SAMPLING 'n_shot_to_samples' SHOTS.
    '''device = create_device(location='local', name='qiskit.shot_simulator')
    qaoa = QAOA()
    qaoa.set_device(device)
    qaoa.set_circuit_properties(**circuit_configuration)
    qaoa.set_backend_properties(n_shots= n_shots_to_sample)
    qaoa.compile(jrp_ising)'''
        
    # STEP 4: THE MEASUREMENTS OUTCUMES OF THE Q_RESULT ARE REPLACED WITH THE NEW ONES
    bootstrap_measurement_outcomes = np.random.choice(
        keys,
        size=len(original_sample),
        replace=True,
        p=probabilities # this bias the choice prob. according to the frequency a bitstring was measured
        )
    bootstrap_measurement_outcomes = dict(Counter(bootstrap_measurement_outcomes)) # the bootstrap sample is saved as OpenQAOA require (bitstring,freq.)
    q_result.optimized["measurement_outcomes"] = bootstrap_measurement_outcomes

    # STEP 2: INITIALIZE IMPORTANT VARIABLES
    #   - 'size' lowest cost bitstrings, in Ising formulation
    solutions_bitstring = q_result.lowest_cost_bitstrings(size)['solutions_bitstrings']
    #   - probabilities of measuring each of the bitstring
    probabilities = q_result.lowest_cost_bitstrings(size)['probabilities']

    # STEP 3: CONVERTS ISING SOLUTIONS TO STANDARD ONES AND CALCULATE ITS PROBABILITIES VARIANCES
    standard_solutions = []
    aux_probabilities = []
    for s,p in zip(solutions_bitstring,probabilities):
        try:
            # if the method raise an error, means that the solution is unfeasible, so it won't be appended to final list
            ss=instance.quboSolution_to_standardSolution(s,check_feasibility=True)
            standard_solutions.append(ss)
            aux_probabilities.append(p)
        except:
            pass
    probabilities = aux_probabilities

    # STEP 4: CALCULATE THE APPROXIMATION RATIOS FOR EACH LOWEST STANDARD SOLUTION
    approximation_ratios = []
    for s in standard_solutions:
        approx_ratio = instance.calculate_standard_gain(s)/optimal_standard_solution_gain
        approximation_ratios.append(round(approx_ratio,4))

    # STEP 5: SUM UP PROBABILITIES OF REPEATED APPROXIMATION RATIOS
    aux_dict = {}
    for ar,p in zip(approximation_ratios,probabilities):
        # if an aaproximation ratio is alredy in the dictionary, it won't replace the key value, instead, it will sum up the new probability
        if str(ar) in aux_dict.keys():
            aux_dict[str(ar)] = aux_dict[str(ar)] + p
        # else, it will initializate with the new probability
        else:
            aux_dict[str(ar)] = p
    approximation_ratios = [float(i) for i in list(aux_dict.keys())]
    probabilities = list(aux_dict.values())

    # STEP 6: calculate the Complementary Cumulative Distribution Function over the probabilities
    # https://en.wikipedia.org/wiki/Cumulative_distribution_function#Complementary_cumulative_distribution_function_(tail_distribution)
    ccdf = []
    for index in range(len(probabilities)):
        ccdf.append(round(np.sum(np.array(probabilities[:index+1])),4))

    # STEP 7: expand the ccdf for over n measures
    measures = range(n_shots_to_extrapolate)
    array_3D = np.zeros((n_shots_to_extrapolate, len(ccdf)))
    for i in range(array_3D.shape[0]):
        for j in range(array_3D.shape[1]):
            array_3D[i,j] = 1-(1-ccdf[j])** measures[i]

    # STEP 8: final plot
    X = approximation_ratios  
    Z = measures  
    Y = array_3D

    if plot:
        make_contourf_plot(X,Z,Y)
    
    # creates a dataframe to return
    df = pd.DataFrame(Y.transpose())
    df.index = X
    df.index.name = 'min. approx.ratio expected'
    df.columns = list(Z)
    df.columns.name = 'measurements'
    return df

# %%
PREPROCESS_TOO_BIG_SAMPLING = False
PREPROCESS_REGULAR_SAMPLING = True

# %% [markdown]
# The following cells do the regular preprocessing for creating the 3-tensor needed for this plot. Since this has alredy been done, the preprocessing is desactivated.

# %%
### the size will be 80% of all possible states (2**N * 0.8)
size_multiplier = 0.8

halt = True
if PREPROCESS_REGULAR_SAMPLING:
    directory1 = './results/contourf_plots/regular_sampling'
   
    for index in range(5):

        if index in [0,1]:
            continue
        for key in list(keys):
            if key == 'conf_jrpInitConf6_circuitConf1':
                halt = False
            if halt:
                continue
            directory2 = directory1+'/'+str(key)
            if not os.path.exists(directory2):
                os.makedirs(directory2)                           
        
            print(key+' - sample '+str(index))
            directory3 = directory2 +'/'+str(index)+'.json'

            n_states = 2**(files[key]['jrp_configuration']['num_agents'] * files[key]['jrp_configuration']['num_vacnJobs'])
            size = round(size_multiplier * n_states)
            circuit_configuration = files[key]['circuit_configuration']
            
            df = tensor3_for_approximation_ratio(
                files[key][str(index)],
                circuit_configuration,
                size=size,
                n_shots_for_original_sample=10000,
                n_shots_to_extrapolate=500,
                n_bootstraps=1000,
                directory=directory3,
                plot=False
            )
# 63 mins - n_shots_for_original_sample=100000 - n_shots_to_extrapolate=100 - n_bootstraps=3000
# Out:
# conf_jrpInitConf6_circuitConf1 - sample 2
# taking bootstrap 0
# taking bootstrap 1
# taking bootstrap 2
# taking bootstrap 3
# taking bootstrap 4
# taking bootstrap 5
# taking bootstrap 6
# postprocessing CCDF 471
# postprocessing CCDF 472
# postprocessing CCDF 473
# postprocessing CCDF 474
# postprocessing CCDF 475
# postprocessing CCDF 476
# postprocessing CCDF 477
# postprocessing CCDF 478
# postprocessing CCDF 479
# postprocessing CCDF 480
# postprocessing CCDF 481
# postprocessing CCDF 482
# postprocessing CCDF 483
# postprocessing CCDF 484
# postprocessing CCDF 485
# postprocessing CCDF 486
# postprocessing CCDF 487
# postprocessing CCDF 488
# postprocessing CCDF 489
# postprocessing CCDF 490
# postprocessing CCDF 491
# postprocessing CCDF 492
# postprocessing CCDF 493
# postprocessing CCDF 494
# postprocessing CCDF 495
# postprocessing CCDF 496
# postprocessing CCDF 497
# postprocessing CCDF 498
# postprocessing CCDF 499
# conf_jrpInitConf6_circuitConf2 - sample 2
# taking bootstrap 0
# taking bootstrap 1
# taking bootstrap 2
# taking bootstrap 3
# taking bootstrap 4
# taking bootstrap 5
# taking bootstrap 6
# taking bootstrap 7
# taking bootstrap 8
# taking bootstrap 9
# taking bootstrap 10
# taking bootstrap 11
# taking bootstrap 12
# taking bootstrap 13
# taking bootstrap 14
# taking bootstrap 15
# taking bootstrap 16
# taking bootstrap 17
# taking bootstrap 18
# taking bootstrap 19
# taking bootstrap 20
# taking bootstrap 21
# taking bootstrap 22
# taking bootstrap 23
# taking bootstrap 24
# taking bootstrap 25
# taking bootstrap 26
# taking bootstrap 27
# taking bootstrap 28
# taking bootstrap 29
# taking bootstrap 30
# taking bootstrap 31
# taking bootstrap 32
# taking bootstrap 33
# taking bootstrap 34
# taking bootstrap 35
# taking bootstrap 36
# taking bootstrap 37
# taking bootstrap 38
# taking bootstrap 39
# taking bootstrap 40
# taking bootstrap 41
# taking bootstrap 42
# taking bootstrap 43
# taking bootstrap 44
# taking bootstrap 45
# taking bootstrap 46
# taking bootstrap 47
# taking bootstrap 48
# taking bootstrap 49
# taking bootstrap 50
# taking bootstrap 51
# taking bootstrap 52
# taking bootstrap 53
# taking bootstrap 54
# taking bootstrap 55
# taking bootstrap 56
# taking bootstrap 57
# taking bootstrap 58
# taking bootstrap 59
# taking bootstrap 60
# taking bootstrap 61
# taking bootstrap 62
# taking bootstrap 63
# taking bootstrap 64
# taking bootstrap 65
# taking bootstrap 66
# taking bootstrap 67
# taking bootstrap 68
# taking bootstrap 69
# taking bootstrap 70
# taking bootstrap 71
# taking bootstrap 72
# taking bootstrap 73
# taking bootstrap 74
# taking bootstrap 75
# taking bootstrap 76
# taking bootstrap 77
# taking bootstrap 78
# taking bootstrap 79
# taking bootstrap 80
# taking bootstrap 81
# taking bootstrap 82
# taking bootstrap 83
# taking bootstrap 84
# taking bootstrap 85
# taking bootstrap 86
# taking bootstrap 87
# taking bootstrap 88
# taking bootstrap 89
# taking bootstrap 90
# taking bootstrap 91
# taking bootstrap 92
# taking bootstrap 93
# taking bootstrap 94
# taking bootstrap 95
# taking bootstrap 96
# taking bootstrap 97
# taking bootstrap 98
# taking bootstrap 99
# taking bootstrap 100
# taking bootstrap 101
# taking bootstrap 102
# taking bootstrap 103
# KeyboardInterrupt

# %% [markdown]
# The following cells do the preprocessing for creating the 3-tensor needed for this plot. Since this has alredy been done, the preprocessing is desactivated.

# %%
n_shots_multiplier = {'jrpInitConf0':1500,
          'jrpInitConf1':1500,
          'jrpInitConf2':200,
          'jrpInitConf3':200,
          'jrpInitConf4':50,
          'jrpInitConf5':50,
          'jrpInitConf6':800}

# the size will be 80% of all possible states (2**N * 0.8)
size_multiplier = 0.8

if PREPROCESS_TOO_BIG_SAMPLING:
    directory1 = './results/contourf_plots/too_big_sampling'
    
    for key in list(keys):
        directory2 = directory1+'/'+str(key)
        if not os.path.exists(directory2):
            os.makedirs(directory2)                           
        
        for index in range(5):
            print(key+str(index))#,end='\r')
            directory3 = directory2 +'/'+str(index)+'.json'

            n_states = 2**(files[key]['jrp_configuration']['num_agents'] * files[key]['jrp_configuration']['num_vacnJobs'])

            for key_nshots,current_n_shots in n_shots_multiplier.items():
                if key_nshots in key: 
                    n_shots_to_sample = current_n_shots * n_states
                    break
            size = round(size_multiplier * n_states)
            circuit_configuration = files[key]['circuit_configuration']
            print(f'nshots:{n_shots_to_sample}, size:{size}')
            
            df = tensor3_for_approximation_ratio(
                files[key][str(index)],
                circuit_configuration,
                size=size,
                n_shots_to_sample=n_shots_to_sample,
                n_shots_to_extrapolate=1000,
                directory=directory3,
                plot=False
            )

# %% [markdown]
# We read each preprocessed file of the regular sampling into the notebook

# %%
directory = './results/contourf_plots/regular_sampling'
axises = {}
  
for subdirectory in os.listdir(directory):
        axises[subdirectory] = []
        
        subdirectory_route = os.path.join(directory, subdirectory)
        if os.path.isdir(subdirectory_route):  #verify if directory            
            # read JSONs in sudirectory
            for file in os.listdir(subdirectory_route):
                print(f"{subdirectory} - sample {file}")
                file_route = os.path.join(subdirectory_route, file)
                
                if file.endswith('.json'):  # verift if json
                    with open(file_route, 'r', encoding='utf-8') as f:
                        content = json.load(f)
                        axises[subdirectory].append(content)
# Out:
# conf_jrpInitConf0_circuitConf0 - sample 0.json
# conf_jrpInitConf0_circuitConf0 - sample 0_errormargin1.png
# conf_jrpInitConf0_circuitConf0 - sample 0_mean.png
# conf_jrpInitConf0_circuitConf0 - sample 1.json
# conf_jrpInitConf0_circuitConf0 - sample 1.png
# conf_jrpInitConf0_circuitConf0 - sample 2.json
# conf_jrpInitConf0_circuitConf0 - sample 2.png
# conf_jrpInitConf0_circuitConf0 - sample 3.json
# conf_jrpInitConf0_circuitConf0 - sample 3.png
# conf_jrpInitConf0_circuitConf0 - sample 4.json
# conf_jrpInitConf0_circuitConf0 - sample 4.png
# conf_jrpInitConf0_circuitConf1 - sample 0.json
# conf_jrpInitConf0_circuitConf1 - sample 0.png
# conf_jrpInitConf0_circuitConf1 - sample 1.json
# conf_jrpInitConf0_circuitConf1 - sample 1.png
# conf_jrpInitConf0_circuitConf1 - sample 2.json
# conf_jrpInitConf0_circuitConf1 - sample 2.png
# conf_jrpInitConf0_circuitConf1 - sample 3.json
# conf_jrpInitConf0_circuitConf1 - sample 3.png
# conf_jrpInitConf0_circuitConf1 - sample 4.json
# conf_jrpInitConf0_circuitConf1 - sample 4.png
# conf_jrpInitConf0_circuitConf2 - sample 0.json
# conf_jrpInitConf0_circuitConf2 - sample 0.png
# conf_jrpInitConf0_circuitConf2 - sample 1.json
# conf_jrpInitConf0_circuitConf2 - sample 1.png
# conf_jrpInitConf0_circuitConf2 - sample 2.json
# conf_jrpInitConf0_circuitConf2 - sample 2.png
# conf_jrpInitConf0_circuitConf2 - sample 3.json
# conf_jrpInitConf0_circuitConf2 - sample 3.png
# conf_jrpInitConf0_circuitConf2 - sample 4.json
# conf_jrpInitConf0_circuitConf2 - sample 4.png
# conf_jrpInitConf1_circuitConf0 - sample 0.json
# conf_jrpInitConf1_circuitConf0 - sample 0.png
# conf_jrpInitConf1_circuitConf0 - sample 1.json
# conf_jrpInitConf1_circuitConf0 - sample 1.png
# conf_jrpInitConf1_circuitConf0 - sample 2.json
# conf_jrpInitConf1_circuitConf0 - sample 2.png
# conf_jrpInitConf1_circuitConf0 - sample 3.json
# conf_jrpInitConf1_circuitConf0 - sample 3.png
# conf_jrpInitConf1_circuitConf0 - sample 4.json
# conf_jrpInitConf1_circuitConf0 - sample 4.png
# conf_jrpInitConf1_circuitConf1 - sample 0.json
# conf_jrpInitConf1_circuitConf1 - sample 0.png
# conf_jrpInitConf1_circuitConf1 - sample 1.json
# conf_jrpInitConf1_circuitConf1 - sample 1.png
# conf_jrpInitConf1_circuitConf1 - sample 2.json
# conf_jrpInitConf1_circuitConf1 - sample 2.png
# conf_jrpInitConf1_circuitConf1 - sample 3.json
# conf_jrpInitConf1_circuitConf1 - sample 3.png
# conf_jrpInitConf1_circuitConf1 - sample 4.json
# conf_jrpInitConf1_circuitConf1 - sample 4.png
# conf_jrpInitConf1_circuitConf2 - sample 0.json
# conf_jrpInitConf1_circuitConf2 - sample 0.png
# conf_jrpInitConf1_circuitConf2 - sample 1.json
# conf_jrpInitConf1_circuitConf2 - sample 1.png
# conf_jrpInitConf1_circuitConf2 - sample 2.json
# conf_jrpInitConf1_circuitConf2 - sample 2.png
# conf_jrpInitConf1_circuitConf2 - sample 3.json
# conf_jrpInitConf1_circuitConf2 - sample 3.png
# conf_jrpInitConf1_circuitConf2 - sample 4.json
# conf_jrpInitConf1_circuitConf2 - sample 4.png
# conf_jrpInitConf2_circuitConf0 - sample 0.json
# conf_jrpInitConf2_circuitConf0 - sample 0.png
# conf_jrpInitConf2_circuitConf0 - sample 1.json
# conf_jrpInitConf2_circuitConf0 - sample 1.png
# conf_jrpInitConf2_circuitConf0 - sample 2.json
# conf_jrpInitConf2_circuitConf0 - sample 2.png
# conf_jrpInitConf2_circuitConf0 - sample 3.json
# conf_jrpInitConf2_circuitConf0 - sample 3.png
# conf_jrpInitConf2_circuitConf0 - sample 4.json
# conf_jrpInitConf2_circuitConf0 - sample 4.png
# conf_jrpInitConf2_circuitConf1 - sample 0.json
# conf_jrpInitConf2_circuitConf1 - sample 0.png
# conf_jrpInitConf2_circuitConf1 - sample 1.json
# conf_jrpInitConf2_circuitConf1 - sample 1.png
# conf_jrpInitConf2_circuitConf1 - sample 2.json
# conf_jrpInitConf2_circuitConf1 - sample 2.png
# conf_jrpInitConf2_circuitConf1 - sample 3.json
# conf_jrpInitConf2_circuitConf1 - sample 3.png
# conf_jrpInitConf2_circuitConf1 - sample 4.json
# conf_jrpInitConf2_circuitConf1 - sample 4.png
# conf_jrpInitConf2_circuitConf2 - sample 0.json
# conf_jrpInitConf2_circuitConf2 - sample 0.png
# conf_jrpInitConf2_circuitConf2 - sample 1.json
# conf_jrpInitConf2_circuitConf2 - sample 1.png
# conf_jrpInitConf2_circuitConf2 - sample 2.json
# conf_jrpInitConf2_circuitConf2 - sample 2.png
# conf_jrpInitConf2_circuitConf2 - sample 3.json
# conf_jrpInitConf2_circuitConf2 - sample 3.png
# conf_jrpInitConf2_circuitConf2 - sample 4.json
# conf_jrpInitConf2_circuitConf2 - sample 4.png
# conf_jrpInitConf3_circuitConf0 - sample 0.json
# conf_jrpInitConf3_circuitConf0 - sample 0.png
# conf_jrpInitConf3_circuitConf0 - sample 1.json
# conf_jrpInitConf3_circuitConf0 - sample 1.png
# conf_jrpInitConf3_circuitConf0 - sample 2.json
# conf_jrpInitConf3_circuitConf0 - sample 2.png
# conf_jrpInitConf3_circuitConf0 - sample 3.json
# conf_jrpInitConf3_circuitConf0 - sample 3.png
# conf_jrpInitConf3_circuitConf0 - sample 4.json
# conf_jrpInitConf3_circuitConf0 - sample 4.png
# conf_jrpInitConf3_circuitConf1 - sample 0.json
# conf_jrpInitConf3_circuitConf1 - sample 0.png
# conf_jrpInitConf3_circuitConf1 - sample 1.json
# conf_jrpInitConf3_circuitConf1 - sample 1.png
# conf_jrpInitConf3_circuitConf1 - sample 2.json
# conf_jrpInitConf3_circuitConf1 - sample 2.png
# conf_jrpInitConf3_circuitConf1 - sample 3.json
# conf_jrpInitConf3_circuitConf1 - sample 3.png
# conf_jrpInitConf3_circuitConf1 - sample 4.json
# conf_jrpInitConf3_circuitConf1 - sample 4.png
# conf_jrpInitConf3_circuitConf2 - sample 0.json
# conf_jrpInitConf3_circuitConf2 - sample 0.png
# conf_jrpInitConf3_circuitConf2 - sample 1.json
# conf_jrpInitConf3_circuitConf2 - sample 1.png
# conf_jrpInitConf3_circuitConf2 - sample 2.json
# conf_jrpInitConf3_circuitConf2 - sample 2.png
# conf_jrpInitConf3_circuitConf2 - sample 3.json
# conf_jrpInitConf3_circuitConf2 - sample 3.png
# conf_jrpInitConf3_circuitConf2 - sample 4.json
# conf_jrpInitConf3_circuitConf2 - sample 4.png
# conf_jrpInitConf4_circuitConf0 - sample 0.json
# conf_jrpInitConf4_circuitConf0 - sample 0.png
# conf_jrpInitConf4_circuitConf0 - sample 1.json
# conf_jrpInitConf4_circuitConf0 - sample 1.png
# conf_jrpInitConf4_circuitConf0 - sample 2.json
# conf_jrpInitConf4_circuitConf0 - sample 2.png
# conf_jrpInitConf4_circuitConf0 - sample 3.json
# conf_jrpInitConf4_circuitConf0 - sample 3.png
# conf_jrpInitConf4_circuitConf0 - sample 4.json
# conf_jrpInitConf4_circuitConf0 - sample 4.png
# conf_jrpInitConf6_circuitConf0 - sample 2.png
# conf_jrpInitConf6_circuitConf0 - sample 3.json
# conf_jrpInitConf6_circuitConf0 - sample 3.png
# conf_jrpInitConf6_circuitConf0 - sample 4.json
# conf_jrpInitConf6_circuitConf0 - sample 4.png
# conf_jrpInitConf6_circuitConf1 - sample 0.json
# conf_jrpInitConf6_circuitConf1 - sample 0.png
# conf_jrpInitConf6_circuitConf1 - sample 1.json
# conf_jrpInitConf6_circuitConf1 - sample 1.png
# conf_jrpInitConf6_circuitConf1 - sample 2.json
# conf_jrpInitConf6_circuitConf1 - sample 2.png
# conf_jrpInitConf6_circuitConf1 - sample 3.json
# conf_jrpInitConf6_circuitConf1 - sample 3.png
# conf_jrpInitConf6_circuitConf1 - sample 4.json
# conf_jrpInitConf6_circuitConf1 - sample 4.png
# conf_jrpInitConf6_circuitConf2 - sample 0.json
# conf_jrpInitConf6_circuitConf2 - sample 0.png
# conf_jrpInitConf6_circuitConf2 - sample 1.json
# conf_jrpInitConf6_circuitConf2 - sample 1.png
# conf_jrpInitConf6_circuitConf2 - sample 2.json
# conf_jrpInitConf6_circuitConf2 - sample 2.png
# conf_jrpInitConf6_circuitConf2 - sample 3.json
# conf_jrpInitConf6_circuitConf2 - sample 3.png
# conf_jrpInitConf6_circuitConf2 - sample 4.json
# conf_jrpInitConf6_circuitConf2 - sample 4.png

# %% [markdown]
# Create each image individually and then in a global image. This has alredy been done.

# %%
CREATE_IMAGES = True

# %%
if CREATE_IMAGES:
    for i,key in enumerate(keys):
        instances = axises[str(key)]
        if key not in 'conf_jrpInitConf0_circuitConf0':
            continue
        for j,instance in enumerate(instances):
            if j != 0:
                continue
            values = list(instance.values())
            X,Z,Y_mean,Y_errormargin = values[:4]
            if SAVE_IN_ENGLISH:
                dir_mean = 'results/contourf_plots/regular_sampling/'+str(key)+'/'+str(j)+'_mean.png'
                make_contourf_plot(X,Z,Y_mean,z_label='Mean probability',directory=dir_mean)
                dir_errormargin = 'results/contourf_plots/regular_sampling/'+str(key)+'/'+str(j)+'_errormargin.png'
                make_contourf_plot(X,Z,Y_errormargin,z_label='Probability error margin',directory=dir_errormargin)
            else:
                dir_mean = '../../spanish_imgs/notebooks/results/contourf_plots/'+str(key)+'/'+str(j)+'_media.pdf'
                make_contourf_plot(X,Z,Y_mean,
                                   x_label='',
                                   y_label='',
                                   z_label='Probabilidad media'
                                   ,directory=dir_mean)
            #plt.show()
            plt.close()

# %%
if CREATE_IMAGES:
    fig, axs = plt.subplots(nrows=21, ncols=5, figsize=(40, 100))
    plt.subplots_adjust(hspace=0.5, wspace=0.3)
    for i,key in enumerate(keys):
        instances = axises[str(key)]
        for j,instance in enumerate(instances):
            values = list(instance.values())
            X,Z,Y = values[:3]            
            make_contourf_plot(X,Z,Y,ax=axs[i,j])

    if SAVE_IN_ENGLISH:
        col_labels = [f'instance {i+1}' for i in range(5)]      
        row_labels = [f'Row {i}' for i in range(21)]
        row_labels = [str(i[5:17]+'\n'+str(i[18:])) for i in keys]
        row_labels = ['Configuration\n'+str(i) for i in configurations_names]
        dir = 'results/contourf_plots/regular_sampling/imgs.png'
    else:
        col_labels = [f'Instancia {i+1}' for i in range(5)]      
        row_labels = [f'Fila {i}' for i in range(21)]
        row_labels = [str(i[5:17]+'\n'+str(i[18:])) for i in keys]
        row_labels = ['Configuración\n'+str(i) for i in configurations_names]
        dir = '../../spanish_imgs/notebooks/results/contourf_plots/imgs.png'
    for j, label in enumerate(col_labels):
        axs[0, j].set_title(label, pad=10,fontsize=20)

    for i, label in enumerate(row_labels):
        axs[i, 0].set_ylabel(label, rotation=45, labelpad=40,fontsize=18)
    fig.savefig(dir, bbox_inches='tight')
    #plt.show()
    plt.close()

# %% [markdown]
# The complete global images for the 105 instances is shown below.

# %% [markdown]
# ## Measurements needed for ensure a minimal approximation ratio with a particular probability

# %%
subkeys = []
probability = 0.9

for index in range(0,len(data)-6,6):
    subkeys.append([keys[index],keys[index+1],keys[index+2],keys[index+3],keys[index+4],keys[index+5]])
subkeys.insert(1,[keys[18],keys[19],keys[20]])

fig, ax = plt.subplots(figsize=(6, 4))

if SAVE_IN_ENGLISH:
    labels = ['problem size 15','problem size 16','problem size 18','problem size 20']
    x_label = None
    y_label = None
    dir = f'results/contour_plots/contour_plot_per_problem_size.png'
else:
    labels = ['Tamaño de prob. 15','Tamaño de prob. 16','Tamaño de prob. 18','Tamaño de prob. 20']
    x_label = 'Mínima Razón de Aproximación\nesperada con una probabilidad de '+str(probability)
    y_label = 'Mediciones requeridas'
    dir = f'../../spanish_imgs/notebooks/results/contour_plots/contour_plot_per_problem_size.png'

for index,sks in enumerate(subkeys):
    Xs=[]
    Zs=[]
    Ys=[]
    for sk in sks: 
        Xs = Xs+[axises[str(sk)][i]['X'] for i in range(5)]
        Zs = Zs+[axises[str(sk)][i]['Z'] for i in range(5)]
        Ys = Ys+[axises[str(sk)][i]['Y'] for i in range(5)]
    make_average_contour_plot(Xs,Zs,Ys,x_label=x_label,y_label=y_label,probability=probability,ax=ax,plot_label=labels[index])
#plt.show()
plt.tight_layout()
plt.savefig(dir)
plt.show()

# %%
subkeys = []
for index in range(0,3):
    aux = []
    for index2 in range(0,21,3):
        aux.append(keys[index+index2])
    subkeys.append(aux)
fig, ax = plt.subplots(figsize=(6, 4))

if SAVE_IN_ENGLISH:
    x_label = None
    y_label = None
    dir = f'results/contour_plots/contour_plot_per_p.png'
else:
    x_label = 'Mínima Razón de Aproximación\nesperada con una probabilidad de '+str(probability)
    y_label = 'Mediciones requeridas'
    dir = f'../../spanish_imgs/notebooks/results/contour_plots/contour_plot_per_p.png'
labels = ['p=3','p=4','p=5']
for index,sks in enumerate(subkeys):
    Xs=[]
    Zs=[]
    Ys=[]
    for sk in sks: 
        Xs = Xs+[axises[str(sk)][i]['X'] for i in range(5)]
        Zs = Zs+[axises[str(sk)][i]['Z'] for i in range(5)]
        Ys = Ys+[axises[str(sk)][i]['Y'] for i in range(5)]
    make_average_contour_plot(Xs,Zs,Ys,x_label=x_label,y_label=y_label,probability=0.9,ax=ax,plot_label=labels[index])
#plt.show()
plt.tight_layout()
plt.savefig(dir)
plt.show()
